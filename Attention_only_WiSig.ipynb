# %% [markdown]
# ## Utilities Functions

# %%
import numpy as np
import pickle
import os
import os.path




def load_from_full_dataset(full_dataset_path, capture_date,rx_name,prefix=None):
    src=full_dataset_path

    if prefix is None: 
        dataset_path = '{}pkl_wifi_{}/dataset_{}_node{}.pkl'.format(src,capture_date,capture_date,rx_name)
    else:
        dataset_path = '{}pkl_wifi_{}_{}/dataset_{}_node{}.pkl'.format(src,prefix,capture_date,capture_date,rx_name)
   
    if os.path.isfile(dataset_path) :
        with open(dataset_path,'rb') as f:
            dataset = pickle.load(f)
    else:
            dataset = None
#             print('Not Found')
#             print(dataset_path)
    return dataset


def load_compact_pkl_dataset(dataset_path,dataset_name):
    with open(dataset_path+dataset_name+'.pkl','rb') as f:
        dataset = pickle.load(f)
    return dataset


def shuffle(vec1,vec2,seed = 0):
    np.random.seed(0)
#     print(vec1.shape[0],vec2.shape[0])
    shfl_indx = np.arange(vec1.shape[0])
    np.random.shuffle(shfl_indx)
    shfl_indx = shfl_indx.astype('int')
    vec1 = vec1[shfl_indx]
    vec2 = np.copy(vec2[shfl_indx])
    return vec1,vec2


def norm(sig_u):
    if len(sig_u.shape)==3:
        pwr = np.sqrt(np.mean(np.sum(sig_u**2,axis = -1),axis = -1))
        sig_u = sig_u/pwr[:,None,None]
    if len(sig_u.shape)==2:
        pwr =  np.sqrt(np.mean(np.sum(sig_u**2,axis = -1),axis = -1))
        sig_u = sig_u/pwr
    # print(sig_u.shape)
    return sig_u

def split3(vec,n1,n2):
    vec1 = vec[0:n1]
    vec2 = vec[n1:n1+n2]
    vec3 = vec[n1+n2:]
    return vec3,vec1,vec2

def split_set3(st,f1,f2):
    [sig,txid] = st

    n_samples  = sig.shape[0]
    n1 = int(f1*n_samples)
    n2 = int(f2*n_samples)

    sig1,sig2,sig3 = split3(sig,n1,n2)
    txid1,txid2,txid3 = split3(txid,n1,n2)
    st1 = [sig1,txid1]
    st2 = [sig2,txid2]
    st3 = [sig3,txid3]
    return st1,st2,st3 

def get_node_indices(tx_name_list,node_name_list):
    op_list = []
    for tx in tx_name_list:
        if tx in node_name_list:
            op_list.append(node_name_list.index(tx))
        else:
            op_list.append(None)
    return op_list
    
def parse_nodes(dataset,node_list,seed = 0):
    cat_sig = []
    cat_txid = []
    data = dataset['data']
    
    
    for i,node in enumerate(node_list):
        if (not node  is  None) and  node < len(data):
            cat_sig.append(data[node])
            cat_txid.append(np.ones( (data[node].shape[0]) )*i)
    cat_sig = np.concatenate(cat_sig)
    cat_txid = np.concatenate(cat_txid)
    np.random.seed(seed)
    cat_sig,cat_txid = shuffle(cat_sig,cat_txid)
    cat_sig = norm(cat_sig)
    return (cat_sig,cat_txid)

def to_categorical(y, num_classes=None, dtype='float32'):
    y = np.array(y, dtype='int')
    input_shape = y.shape
    if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
        input_shape = tuple(input_shape[:-1])
    y = y.ravel()
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes), dtype=dtype)
    categorical[np.arange(n), y] = 1
    output_shape = input_shape + (num_classes,)
    categorical = np.reshape(categorical, output_shape)
    return categorical

def prepare_txid_and_weights(st,n):
    sig,txid = st
    txid_oh = to_categorical(txid,n)
    stat= np.sum(txid_oh,axis=0)
    cls_weights = np.max(stat,axis=0)/stat 
    cls_weights = cls_weights.tolist()
    augset = [sig,txid,txid_oh,cls_weights]
    return augset

def prepare_dataset(dataset,tx_name_list,val_frac=0.1, test_frac=0.1):
    tx_list = get_node_indices(tx_name_list,dataset['node_list'])
    all_set = parse_nodes(dataset,tx_list,seed = 0)
    train_set,val_set,test_set = split_set3(all_set,val_frac, test_frac)
    train_augset = prepare_txid_and_weights(train_set,len(tx_list))
    val_augset = prepare_txid_and_weights(val_set,len(tx_list))
    test_augset = prepare_txid_and_weights(test_set,len(tx_list))
    return train_augset,val_augset,test_augset


def create_dataset_impl(tx_list,rx_list,capture_date_list,max_sig=None,equalized_list=[0],full_dataset_path = 'data/',op_dataset_file = None):
    dataset = {}
    dataset['tx_list'] = tx_list
    dataset['rx_list'] = rx_list
    dataset['capture_date_list']=capture_date_list
    dataset['equalized_list'] = equalized_list
    dataset['max_sig'] = max_sig
    
    n_tx = len(tx_list)
    n_rx = len(rx_list)
    n_day = len(capture_date_list)
    n_eq = len(equalized_list)
    
    prefix_lut = [None,'eq']
    
    prefix_list = [prefix_lut[tt] for tt in  equalized_list]
    
    dataset['data'] = [ [ [ [ [ ] for _ in range(n_eq)] for _ in range(n_day) ] for _ in range(n_rx) ]  for _ in range(n_tx)     ]
    
    
    missing_rx_dict = {}
    
    missing_files = False

    
    with open('IdSig_info.pkl','rb') as f:
        IdSig_info=pickle.load(f)
    
    slc = slice(None,max_sig)
    for day_i,capture_date in enumerate(capture_date_list):
        for rx_i,rx_train in enumerate(rx_list):
            for eq_i,prefix in enumerate(prefix_list):
                tdataset = load_from_full_dataset(full_dataset_path,capture_date,rx_train,prefix=prefix)
                if not tdataset is None:
                    for tx_i,tx in enumerate(tx_list):
                        if tx in tdataset['node_list']:
                            tx_indx = tdataset['node_list'].index(tx)
                            dataset['data'][tx_i][rx_i][day_i][eq_i]= tdataset['data'][tx_indx][slc]  
                        else:
                            dataset['data'][tx_i][rx_i][day_i][eq_i]=np.zeros((0,256,2))
                else:
                    missing_rx_name =rx_list[rx_i]  
                    eq_val = equalized_list[eq_i]
                    IdSig_info_sub  = IdSig_info[eq_val][capture_date]
                    if missing_rx_name  in IdSig_info_sub.keys():
                            missing_files = True
                            if not eq_val in  missing_rx_dict.keys():
                                missing_rx_dict[eq_val]={}
                            if not capture_date in  missing_rx_dict[eq_val].keys():
                                missing_rx_dict[eq_val][capture_date]=[]
                            missing_rx_info  = IdSig_info_sub[missing_rx_name]
                            missing_rx_dict[eq_val][capture_date].append(   (missing_rx_info['name'], missing_rx_info['link'],missing_rx_info['size']) )

    
    if missing_files:
        ii=1
        total_file_sizes = 0
        print('You have missing files that you need to download.')
        
        for eq_k  in missing_rx_dict.keys():  
            if len(missing_rx_dict[eq_val])>0:
                print('')
                if eq_k==0:
                    print('You need to download the following files for the non equalized dataset')
                else:
                    print('You need to download the following files for the equalized dataset')
                
                print('')
                
                for date_k  in missing_rx_dict[eq_k].keys():  
                    for missing_rx in missing_rx_dict[eq_val][date_k]:
                        print('{}) Name: {} , Size: {} MB'.format(ii,missing_rx[0],missing_rx[2]/1e6))
                        total_file_sizes=total_file_sizes+missing_rx[2]
                        ii=ii+1
                print('Links:')
                for date_k  in missing_rx_dict[eq_k].keys():  
                    for missing_rx in missing_rx_dict[eq_val][date_k]:
                        print('https://drive.google.com/u/0/uc?export=download&id={}'.format(missing_rx[1]))               
        print('')
        print('You need to dowlnoad {} GB'.format(total_file_sizes/1e9))
        print('Note the following:')
        print('1) The non-equalized and eqalized files need to be downloaded in different fodlers because they share the same exact names')
        print('2) The  non-equalized folders needs to be grouped by date and equalization using the same structure as the following google drive folder')
        print('https://drive.google.com/drive/folders/1r8cd4zZ7fwvN_iiyI_uDKbIFGZve49lw?usp=sharing')
        print('3) If you have already downloaded the files make sure that the full dataset path is configured correctly.')
        dataset = None
    else:
        if not op_dataset_file is None:
            with open(op_dataset_file,'wb') as f:
                pickle.dump(dataset,f)
                print('Dataset saved in {}'.format(op_dataset_file))

    return dataset


def merge_compact_dataset(compact_dataset,capture_date,tx_list,rx_list,max_sig=None,equalized=0):
    dataset = {}
    dataset['node_list'] = tx_list
    dataset['data'] = [ () for _ in range(len(tx_list))]
    
    if not type(capture_date) is list: 
        capture_date_list = [capture_date]
    else:
        capture_date_list = capture_date
    slc = slice(None,max_sig)
    for capture_date in capture_date_list:
        for rx_train in rx_list:
            for indx,tx in enumerate(tx_list):
                tx_i=compact_dataset['tx_list'].index(tx)
                rx_i=compact_dataset['rx_list'].index(rx_train)
                date_i=compact_dataset['capture_date_list'].index(capture_date)
                eq_i=compact_dataset['equalized_list'].index(equalized)
                dataset['data'][indx]  +=  (compact_dataset['data'][tx_i][rx_i][date_i][eq_i][slc],)
    for indx in range(len(tx_list)):
        if len(dataset['data'][indx])>0:
            dataset['data'][indx] =  np.concatenate(dataset['data'][indx])
        else:
            dataset['data'][indx] =np.zeros((0,256,2))
    return dataset

# %% [markdown]
# ## Model

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
import os.path

import scipy,scipy.spatial
import matplotlib
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
with zipfile.ZipFile("/content/drive/MyDrive/ManyRx.pkl.zip", 'r') as zip_ref:
    zip_ref.extractall("./")

# %%
def load_compact_pkl_dataset(dataset_path,dataset_name):
    with open(dataset_path+dataset_name+'.pkl','rb') as f:
        dataset = pickle.load(f)
    return dataset

compact_dataset = load_compact_pkl_dataset("./","ManyRx")

tx_list = compact_dataset['tx_list']
rx_list = compact_dataset['rx_list']

equalized = 0

capture_date_list = compact_dataset['capture_date_list']
capture_date = capture_date_list[0]
n_tx = len(tx_list)
n_rx = len(rx_list)
print(n_tx,n_rx)
# Out:
# 10 32

# %%
compact_dataset.keys()
# Out:
# dict_keys(['tx_list', 'rx_list', 'capture_date_list', 'equalized_list', 'max_sig', 'data'])

# %%
np.random.seed(0)
n_real = 5
rx_list_real = []
for i in range(n_real):
    np.random.shuffle(rx_list)
    rx_list_real.append(np.copy(rx_list).tolist())
print(rx_list_real)
# Out:
# [['19-20', '24-13', '19-2', '1-20', '20-20', '20-1', '7-7', '3-19', '23-6', '2-19', '24-5', '14-7', '23-1', '19-1', '8-7', '24-6', '24-16', '1-19', '8-8', '18-19', '13-7', '23-3', '8-14', '23-5', '19-19', '18-2', '7-14', '13-14', '1-1', '23-7', '20-19', '2-1'], ['1-1', '23-1', '24-6', '8-8', '1-19', '23-3', '23-5', '7-14', '19-19', '13-14', '23-6', '7-7', '19-1', '20-1', '20-20', '24-16', '8-14', '19-2', '14-7', '1-20', '13-7', '24-5', '18-2', '2-19', '24-13', '19-20', '3-19', '8-7', '20-19', '2-1', '23-7', '18-19'], ['24-5', '23-7', '18-19', '23-3', '24-6', '8-14', '2-1', '13-7', '19-19', '19-2', '18-2', '1-20', '20-1', '24-16', '3-19', '1-19', '24-13', '23-6', '19-1', '8-7', '20-19', '1-1', '14-7', '20-20', '7-7', '2-19', '23-5', '8-8', '19-20', '13-14', '7-14', '23-1'], ['1-20', '1-19', '20-19', '23-7', '2-1', '20-1', '19-19', '14-7', '23-1', '3-19', '8-8', '7-7', '13-7', '20-20', '24-16', '18-2', '8-7', '23-5', '7-14', '18-19', '24-6', '19-1', '13-14', '2-19', '19-20', '24-5', '23-3', '19-2', '8-14', '23-6', '24-13', '1-1'], ['18-19', '20-1', '13-14', '18-2', '14-7', '20-20', '13-7', '19-20', '2-19', '19-19', '19-1', '1-20', '24-5', '20-19', '8-7', '23-1', '7-7', '8-8', '2-1', '1-19', '3-19', '23-3', '23-6', '23-5', '24-6', '8-14', '24-16', '7-14', '1-1', '19-2', '24-13', '23-7']]

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K

# %%
# !pip install attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting attention
#   Downloading attention-5.0.0-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from attention) (1.22.4)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.10/dist-packages (from attention) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.1->attention) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.1->attention) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (3.2.2)
# Installing collected packages: attention
# Successfully installed attention-5.0.0

# %%
# https://github.com/philipperemy/keras-attention
from attention import Attention

# %%
def create_net():

    inputs = Input(shape=(256,2))
    x = Reshape((256,2,1))(inputs)
    #x = Dense(64, activation='relu', kernel_regularizer = keras.regularizers.l2(0.0001))(inputs)
    #x = LSTM(64, return_sequences=True)(inputs)

    x = Conv2D(8,(3,2),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,1))(x)
    x = Conv2D(16,(3,2),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,1))(x)
    x = Reshape((64,32))(x)
    '''
    x = Conv2D(16,(3,2),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,2))(x)
    x = Conv2D(32,(3,1),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,1))(x)
    x = Conv2D(16,(3,1),activation='relu',padding = 'same')(x)
    '''
    x = Attention(units=64)(x)
    #x = LSTM(64, return_sequences=False)(x)
    #x = resnet(x,64,(3,2),'6')
    #x = MaxPool2D((2,2))(x)
    x = Flatten()(x)



    x = Dense(100, activation='relu', kernel_regularizer = keras.regularizers.l2(0.0001))(x)
    # x = Dropout(0.3)(x)
    x = Dense(80, activation='relu',kernel_regularizer = keras.regularizers.l2(0.0001))(x)
    x = Dropout(0.5)(x)
    x = Dense(n_tx, activation='softmax',kernel_regularizer = keras.regularizers.l2(0.0001))(x)
    ops = x

    classifier = Model(inputs,ops)
    classifier.compile(loss='categorical_crossentropy',metrics=['categorical_accuracy'],optimizer=keras.optimizers.Adam(0.0005))
    
    return classifier

classifier = create_net()
classifier.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256, 2)]          0
#
#  reshape_3 (Reshape)         (None, 256, 2, 1)         0
#
#  conv2d_4 (Conv2D)           (None, 256, 2, 8)         56
#
#  max_pooling2d_4 (MaxPooling  (None, 128, 2, 8)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 2, 16)        784
#
#  max_pooling2d_5 (MaxPooling  (None, 64, 2, 16)        0
#  2D)
#
#  reshape_4 (Reshape)         (None, 64, 32)            0
#
#  attention_2 (Attention)     (None, 64)                5120
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 100)               6500
#
#  dense_5 (Dense)             (None, 80)                8080
#
#  dropout_1 (Dropout)         (None, 80)                0
#
#  dense_6 (Dense)             (None, 10)                810
#
# =================================================================
# Total params: 21,350
# Trainable params: 21,350
# Non-trainable params: 0
# _________________________________________________________________

# %%
def evaluate_test(classifier):
    pred = classifier.predict(sig_dfTest)
    acc = np.mean(np.argmax(pred,1)==txidNum_dfTest)

    test_indx = ()
    for indx in range(len(tx_list)):
        cls_indx = np.where(txidNum_dfTest == indx)
        test_indx = test_indx + (cls_indx[0][:n_test_samples],)
    test_indx = np.concatenate(test_indx) 
    acc_bal = np.mean(np.argmax(pred[test_indx,:],1)==txidNum_dfTest[test_indx])
    return acc,acc_bal

# %%
n_test_rx = 5

# %%
# !mkdir weights

# %%
tf.get_logger().setLevel('ERROR')
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
TRAIN = True
continue_training = True
nreal = 5

real_list = list(range(nreal))
nrx_list =  list(range( 0,len(rx_list_real[0])-n_test_rx+1,5))  # [0,len(rx_list_real[0])-1] #

patience = 5
n_epochs = 100

smTest_results = []
dfTest_results = []
dfTestBal_results = []

for real in real_list:
    rx_list = rx_list_real[real]
    rx_test_list = rx_list[-n_test_rx:]
    test_dataset = merge_compact_dataset(compact_dataset,capture_date,tx_list,rx_test_list)
    test_augset_dfRx,_,_ = prepare_dataset(test_dataset,tx_list,val_frac=0.0, test_frac=0.0)

    [sig_dfTest,txidNum_dfTest,txid_dfTest,cls_weights] = test_augset_dfRx
    
    cnt=np.histogram(txidNum_dfTest,bins=np.arange(len(tx_list)+1)-0.5)
    n_test_samples = int(np.min(cnt[0]))

    smTest_results_real = []
    dfTest_results_real = []
    dfTestBal_results_real = []
    for nrx in nrx_list:
        print("");print("")
        print("nrx: {} - real: {} ".format(nrx,real))
        fname_w = 'weights/d003_{:02d}_{:02d}.hd5'.format(nrx,real)
        rx_train_list= rx_list[:nrx+1]

        dataset = merge_compact_dataset(compact_dataset,capture_date,tx_list,rx_train_list)

        train_augset,val_augset,test_augset_smRx =  prepare_dataset(dataset,tx_list,
                                                            val_frac=0.1, test_frac=0.1)
        [sig_train,txidNum_train,txid_train,cls_weights] = train_augset
        [sig_valid,txidNum_valid,txid_valid,_] = val_augset
        [sig_smTest,txidNum_smTest,txid_smTest,cls_weights] = test_augset_smRx
        
        spl_weights = np.zeros((len(sig_train)))
        for index in range(len(txid_train)):
          spl_weights[index] = cls_weights[np.argmax(txid_train[index])]


        if continue_training:
            skip = os.path.isfile(fname_w)
        else:
            skip = False
        classifier = create_net()
        with tf.device('/device:GPU:0'):
          if TRAIN and not skip:
              filepath = 't_weights_0'
              c=[ keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True),
                keras.callbacks.EarlyStopping(monitor='val_loss',  patience=patience)]
              #history = classifier.fit(sig_train,txid_train,class_weight=cls_weights,validation_data=(sig_valid , txid_valid),callbacks=c, epochs=n_epochs)
              history = classifier.fit(sig_train,txid_train,sample_weight=spl_weights,
                                      validation_data=(sig_valid , txid_valid),callbacks=c, epochs=n_epochs, verbose=2)
              classifier.load_weights(filepath)
              classifier.save_weights(fname_w,save_format="h5")
          else:
              classifier.load_weights(fname_w)

        smTest_r = classifier.evaluate(sig_smTest,txid_smTest,verbose=0)[1]
    #     dfTest_r = classifier.evaluate(sig_dfTest,txid_dfTest)[1]
        dfTest_r,dfTestBal_r = evaluate_test(classifier)

        print(smTest_r,dfTest_r)
        smTest_results_real.append(smTest_r)
        dfTest_results_real.append(dfTest_r)
        dfTestBal_results_real.append(dfTestBal_r)
        K.clear_session()
    smTest_results.append(smTest_results_real)
    dfTest_results.append(dfTest_results_real)
    dfTestBal_results.append(dfTestBal_results_real)
# Out:
# <ipython-input-2-e7494fe5acc6>:119: RuntimeWarning: invalid value encountered in true_divide
#   cls_weights = np.max(stat,axis=0)/stat
# nrx: 0 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.30102, saving model to t_weights_0
# 50/50 - 65s - loss: 2.9721 - categorical_accuracy: 0.1163 - val_loss: 2.3010 - val_categorical_accuracy: 0.1200 - 65s/epoch - 1s/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.30102 to 2.25357, saving model to t_weights_0
# 50/50 - 2s - loss: 2.9099 - categorical_accuracy: 0.1394 - val_loss: 2.2536 - val_categorical_accuracy: 0.2050 - 2s/epoch - 38ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 2.25357 to 2.08987, saving model to t_weights_0
# 50/50 - 2s - loss: 2.7597 - categorical_accuracy: 0.2125 - val_loss: 2.0899 - val_categorical_accuracy: 0.3500 - 2s/epoch - 40ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 2.08987 to 1.76344, saving model to t_weights_0
# 50/50 - 2s - loss: 2.4763 - categorical_accuracy: 0.3100 - val_loss: 1.7634 - val_categorical_accuracy: 0.3400 - 2s/epoch - 42ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.76344 to 1.48421, saving model to t_weights_0
# 50/50 - 3s - loss: 2.1283 - categorical_accuracy: 0.4125 - val_loss: 1.4842 - val_categorical_accuracy: 0.4500 - 3s/epoch - 61ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.48421 to 1.24133, saving model to t_weights_0
# 50/50 - 2s - loss: 1.8089 - categorical_accuracy: 0.4750 - val_loss: 1.2413 - val_categorical_accuracy: 0.6050 - 2s/epoch - 37ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.24133 to 1.06863, saving model to t_weights_0
# 50/50 - 2s - loss: 1.5249 - categorical_accuracy: 0.5638 - val_loss: 1.0686 - val_categorical_accuracy: 0.6250 - 2s/epoch - 37ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.06863 to 0.96147, saving model to t_weights_0
# 50/50 - 2s - loss: 1.3088 - categorical_accuracy: 0.6212 - val_loss: 0.9615 - val_categorical_accuracy: 0.6950 - 2s/epoch - 44ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.96147 to 0.89579, saving model to t_weights_0
# 50/50 - 2s - loss: 1.2111 - categorical_accuracy: 0.6675 - val_loss: 0.8958 - val_categorical_accuracy: 0.7300 - 2s/epoch - 37ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.89579 to 0.80443, saving model to t_weights_0
# 50/50 - 2s - loss: 1.1193 - categorical_accuracy: 0.6944 - val_loss: 0.8044 - val_categorical_accuracy: 0.7600 - 2s/epoch - 38ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.80443 to 0.77483, saving model to t_weights_0
# 50/50 - 3s - loss: 1.0452 - categorical_accuracy: 0.7262 - val_loss: 0.7748 - val_categorical_accuracy: 0.7750 - 3s/epoch - 61ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.77483 to 0.72946, saving model to t_weights_0
# 50/50 - 2s - loss: 0.9291 - categorical_accuracy: 0.7606 - val_loss: 0.7295 - val_categorical_accuracy: 0.8250 - 2s/epoch - 42ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.72946
# 50/50 - 0s - loss: 0.8666 - categorical_accuracy: 0.7763 - val_loss: 0.7426 - val_categorical_accuracy: 0.8050 - 238ms/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.72946 to 0.65964, saving model to t_weights_0
# 50/50 - 2s - loss: 0.8384 - categorical_accuracy: 0.8031 - val_loss: 0.6596 - val_categorical_accuracy: 0.8300 - 2s/epoch - 38ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.65964 to 0.65871, saving model to t_weights_0
# 50/50 - 2s - loss: 0.7781 - categorical_accuracy: 0.8062 - val_loss: 0.6587 - val_categorical_accuracy: 0.8500 - 2s/epoch - 45ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.65871
# 50/50 - 0s - loss: 0.7502 - categorical_accuracy: 0.8163 - val_loss: 0.6711 - val_categorical_accuracy: 0.8300 - 250ms/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.65871 to 0.60806, saving model to t_weights_0
# 50/50 - 2s - loss: 0.7017 - categorical_accuracy: 0.8256 - val_loss: 0.6081 - val_categorical_accuracy: 0.8300 - 2s/epoch - 38ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.60806 to 0.58957, saving model to t_weights_0
# 50/50 - 2s - loss: 0.6600 - categorical_accuracy: 0.8388 - val_loss: 0.5896 - val_categorical_accuracy: 0.8550 - 2s/epoch - 37ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.58957 to 0.56463, saving model to t_weights_0
# 50/50 - 3s - loss: 0.6266 - categorical_accuracy: 0.8575 - val_loss: 0.5646 - val_categorical_accuracy: 0.8600 - 3s/epoch - 66ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.56463 to 0.55983, saving model to t_weights_0
# 50/50 - 2s - loss: 0.5979 - categorical_accuracy: 0.8669 - val_loss: 0.5598 - val_categorical_accuracy: 0.8700 - 2s/epoch - 41ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.55983 to 0.53693, saving model to t_weights_0
# 50/50 - 2s - loss: 0.5761 - categorical_accuracy: 0.8644 - val_loss: 0.5369 - val_categorical_accuracy: 0.8750 - 2s/epoch - 38ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.53693
# 50/50 - 0s - loss: 0.5408 - categorical_accuracy: 0.8694 - val_loss: 0.5745 - val_categorical_accuracy: 0.8550 - 245ms/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.53693 to 0.52582, saving model to t_weights_0
# 50/50 - 2s - loss: 0.5221 - categorical_accuracy: 0.8775 - val_loss: 0.5258 - val_categorical_accuracy: 0.8750 - 2s/epoch - 45ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.52582
# 50/50 - 0s - loss: 0.5076 - categorical_accuracy: 0.8925 - val_loss: 0.5326 - val_categorical_accuracy: 0.8750 - 253ms/epoch - 5ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.52582
# 50/50 - 0s - loss: 0.4857 - categorical_accuracy: 0.9031 - val_loss: 0.5435 - val_categorical_accuracy: 0.8850 - 249ms/epoch - 5ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.52582
# 50/50 - 0s - loss: 0.4839 - categorical_accuracy: 0.8900 - val_loss: 0.5293 - val_categorical_accuracy: 0.8750 - 235ms/epoch - 5ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.52582 to 0.51969, saving model to t_weights_0
# 50/50 - 2s - loss: 0.4747 - categorical_accuracy: 0.8963 - val_loss: 0.5197 - val_categorical_accuracy: 0.8850 - 2s/epoch - 39ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.51969
# 50/50 - 0s - loss: 0.4492 - categorical_accuracy: 0.9025 - val_loss: 0.5326 - val_categorical_accuracy: 0.8700 - 239ms/epoch - 5ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.51969
# 50/50 - 0s - loss: 0.4369 - categorical_accuracy: 0.9094 - val_loss: 0.5297 - val_categorical_accuracy: 0.8850 - 241ms/epoch - 5ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.51969 to 0.50195, saving model to t_weights_0
# 50/50 - 3s - loss: 0.4268 - categorical_accuracy: 0.9056 - val_loss: 0.5019 - val_categorical_accuracy: 0.9050 - 3s/epoch - 50ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.50195
# 50/50 - 0s - loss: 0.4002 - categorical_accuracy: 0.9231 - val_loss: 0.5185 - val_categorical_accuracy: 0.8900 - 336ms/epoch - 7ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.50195 to 0.50054, saving model to t_weights_0
# 50/50 - 3s - loss: 0.4049 - categorical_accuracy: 0.9125 - val_loss: 0.5005 - val_categorical_accuracy: 0.9000 - 3s/epoch - 53ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.50054
# 50/50 - 0s - loss: 0.3981 - categorical_accuracy: 0.9137 - val_loss: 0.5023 - val_categorical_accuracy: 0.8950 - 245ms/epoch - 5ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.50054 to 0.48580, saving model to t_weights_0
# 50/50 - 2s - loss: 0.3886 - categorical_accuracy: 0.9194 - val_loss: 0.4858 - val_categorical_accuracy: 0.9050 - 2s/epoch - 39ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.48580
# 50/50 - 0s - loss: 0.3650 - categorical_accuracy: 0.9275 - val_loss: 0.5184 - val_categorical_accuracy: 0.9050 - 236ms/epoch - 5ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.48580 to 0.46700, saving model to t_weights_0
# 50/50 - 2s - loss: 0.3480 - categorical_accuracy: 0.9312 - val_loss: 0.4670 - val_categorical_accuracy: 0.9250 - 2s/epoch - 38ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.46700
# 50/50 - 0s - loss: 0.3464 - categorical_accuracy: 0.9269 - val_loss: 0.4863 - val_categorical_accuracy: 0.9200 - 246ms/epoch - 5ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.46700
# 50/50 - 0s - loss: 0.3519 - categorical_accuracy: 0.9262 - val_loss: 0.5090 - val_categorical_accuracy: 0.9100 - 272ms/epoch - 5ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.46700
# 50/50 - 0s - loss: 0.3354 - categorical_accuracy: 0.9256 - val_loss: 0.5312 - val_categorical_accuracy: 0.9150 - 242ms/epoch - 5ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.46700
# 50/50 - 0s - loss: 0.3153 - categorical_accuracy: 0.9406 - val_loss: 0.5012 - val_categorical_accuracy: 0.9000 - 233ms/epoch - 5ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.46700
# 50/50 - 0s - loss: 0.3140 - categorical_accuracy: 0.9381 - val_loss: 0.5016 - val_categorical_accuracy: 0.9050 - 227ms/epoch - 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# 0.9200000166893005 0.1131
#
#
# nrx: 5 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.28368, saving model to t_weights_0
# 295/295 - 7s - loss: 2.7632 - categorical_accuracy: 0.1238 - val_loss: 2.2837 - val_categorical_accuracy: 0.1644 - 7s/epoch - 24ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.28368 to 2.12966, saving model to t_weights_0
# 295/295 - 3s - loss: 2.6554 - categorical_accuracy: 0.1888 - val_loss: 2.1297 - val_categorical_accuracy: 0.2407 - 3s/epoch - 10ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 2.12966 to 1.95387, saving model to t_weights_0
# 295/295 - 3s - loss: 2.4662 - categorical_accuracy: 0.2513 - val_loss: 1.9539 - val_categorical_accuracy: 0.3059 - 3s/epoch - 10ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.95387 to 1.76216, saving model to t_weights_0
# 295/295 - 4s - loss: 2.2578 - categorical_accuracy: 0.3200 - val_loss: 1.7622 - val_categorical_accuracy: 0.3746 - 4s/epoch - 13ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.76216 to 1.63080, saving model to t_weights_0
# 295/295 - 3s - loss: 2.1030 - categorical_accuracy: 0.3755 - val_loss: 1.6308 - val_categorical_accuracy: 0.4314 - 3s/epoch - 11ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.63080 to 1.54765, saving model to t_weights_0
# 295/295 - 3s - loss: 1.9678 - categorical_accuracy: 0.4235 - val_loss: 1.5477 - val_categorical_accuracy: 0.4805 - 3s/epoch - 10ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.54765 to 1.45422, saving model to t_weights_0
# 295/295 - 3s - loss: 1.8504 - categorical_accuracy: 0.4656 - val_loss: 1.4542 - val_categorical_accuracy: 0.5034 - 3s/epoch - 11ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.45422 to 1.33527, saving model to t_weights_0
# 295/295 - 3s - loss: 1.7409 - categorical_accuracy: 0.5053 - val_loss: 1.3353 - val_categorical_accuracy: 0.5703 - 3s/epoch - 11ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 1.33527 to 1.30804, saving model to t_weights_0
# 295/295 - 4s - loss: 1.6676 - categorical_accuracy: 0.5319 - val_loss: 1.3080 - val_categorical_accuracy: 0.5686 - 4s/epoch - 13ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 1.30804 to 1.21792, saving model to t_weights_0
# 295/295 - 3s - loss: 1.5875 - categorical_accuracy: 0.5554 - val_loss: 1.2179 - val_categorical_accuracy: 0.6246 - 3s/epoch - 10ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 1.21792 to 1.15693, saving model to t_weights_0
# 295/295 - 3s - loss: 1.5038 - categorical_accuracy: 0.5834 - val_loss: 1.1569 - val_categorical_accuracy: 0.6466 - 3s/epoch - 11ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 1.15693 to 1.11222, saving model to t_weights_0
# 295/295 - 3s - loss: 1.4439 - categorical_accuracy: 0.6065 - val_loss: 1.1122 - val_categorical_accuracy: 0.6644 - 3s/epoch - 11ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 1.11222 to 1.08513, saving model to t_weights_0
# 295/295 - 4s - loss: 1.3901 - categorical_accuracy: 0.6257 - val_loss: 1.0851 - val_categorical_accuracy: 0.6754 - 4s/epoch - 13ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 1.08513 to 1.04007, saving model to t_weights_0
# 295/295 - 3s - loss: 1.3429 - categorical_accuracy: 0.6415 - val_loss: 1.0401 - val_categorical_accuracy: 0.6898 - 3s/epoch - 12ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 1.04007 to 1.01528, saving model to t_weights_0
# 295/295 - 3s - loss: 1.2798 - categorical_accuracy: 0.6606 - val_loss: 1.0153 - val_categorical_accuracy: 0.7161 - 3s/epoch - 10ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 1.01528 to 0.96280, saving model to t_weights_0
# 295/295 - 3s - loss: 1.2458 - categorical_accuracy: 0.6687 - val_loss: 0.9628 - val_categorical_accuracy: 0.7220 - 3s/epoch - 11ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.96280 to 0.92235, saving model to t_weights_0
# 295/295 - 4s - loss: 1.1962 - categorical_accuracy: 0.6864 - val_loss: 0.9223 - val_categorical_accuracy: 0.7373 - 4s/epoch - 14ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.92235 to 0.92042, saving model to t_weights_0
# 295/295 - 3s - loss: 1.1632 - categorical_accuracy: 0.6969 - val_loss: 0.9204 - val_categorical_accuracy: 0.7373 - 3s/epoch - 10ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.92042 to 0.88203, saving model to t_weights_0
# 295/295 - 3s - loss: 1.1266 - categorical_accuracy: 0.7084 - val_loss: 0.8820 - val_categorical_accuracy: 0.7466 - 3s/epoch - 10ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.88203 to 0.87828, saving model to t_weights_0
# 295/295 - 4s - loss: 1.0911 - categorical_accuracy: 0.7182 - val_loss: 0.8783 - val_categorical_accuracy: 0.7551 - 4s/epoch - 13ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.87828 to 0.86481, saving model to t_weights_0
# 295/295 - 4s - loss: 1.0606 - categorical_accuracy: 0.7315 - val_loss: 0.8648 - val_categorical_accuracy: 0.7585 - 4s/epoch - 12ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.86481 to 0.81353, saving model to t_weights_0
# 295/295 - 3s - loss: 1.0264 - categorical_accuracy: 0.7424 - val_loss: 0.8135 - val_categorical_accuracy: 0.7797 - 3s/epoch - 11ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.81353 to 0.78579, saving model to t_weights_0
# 295/295 - 3s - loss: 1.0129 - categorical_accuracy: 0.7475 - val_loss: 0.7858 - val_categorical_accuracy: 0.7831 - 3s/epoch - 11ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.78579 to 0.77828, saving model to t_weights_0
# 295/295 - 3s - loss: 0.9736 - categorical_accuracy: 0.7572 - val_loss: 0.7783 - val_categorical_accuracy: 0.7822 - 3s/epoch - 12ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.77828 to 0.73856, saving model to t_weights_0
# 295/295 - 4s - loss: 0.9465 - categorical_accuracy: 0.7632 - val_loss: 0.7386 - val_categorical_accuracy: 0.8042 - 4s/epoch - 12ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.73856
# 295/295 - 1s - loss: 0.9297 - categorical_accuracy: 0.7729 - val_loss: 0.7469 - val_categorical_accuracy: 0.7949 - 1s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.73856 to 0.72065, saving model to t_weights_0
# 295/295 - 3s - loss: 0.8982 - categorical_accuracy: 0.7765 - val_loss: 0.7207 - val_categorical_accuracy: 0.8059 - 3s/epoch - 11ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.72065 to 0.69716, saving model to t_weights_0
# 295/295 - 3s - loss: 0.8757 - categorical_accuracy: 0.7812 - val_loss: 0.6972 - val_categorical_accuracy: 0.8102 - 3s/epoch - 10ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.69716
# 295/295 - 2s - loss: 0.8612 - categorical_accuracy: 0.7878 - val_loss: 0.7009 - val_categorical_accuracy: 0.8042 - 2s/epoch - 5ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.69716
# 295/295 - 2s - loss: 0.8476 - categorical_accuracy: 0.7927 - val_loss: 0.7017 - val_categorical_accuracy: 0.8051 - 2s/epoch - 6ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.69716
# 295/295 - 1s - loss: 0.8174 - categorical_accuracy: 0.7984 - val_loss: 0.6984 - val_categorical_accuracy: 0.8085 - 1s/epoch - 5ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.69716 to 0.65183, saving model to t_weights_0
# 295/295 - 3s - loss: 0.8065 - categorical_accuracy: 0.7984 - val_loss: 0.6518 - val_categorical_accuracy: 0.8237 - 3s/epoch - 10ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.65183 to 0.63684, saving model to t_weights_0
# 295/295 - 3s - loss: 0.7840 - categorical_accuracy: 0.8110 - val_loss: 0.6368 - val_categorical_accuracy: 0.8229 - 3s/epoch - 11ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.63684 to 0.62239, saving model to t_weights_0
# 295/295 - 3s - loss: 0.7606 - categorical_accuracy: 0.8118 - val_loss: 0.6224 - val_categorical_accuracy: 0.8398 - 3s/epoch - 10ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.62239
# 295/295 - 2s - loss: 0.7634 - categorical_accuracy: 0.8097 - val_loss: 0.6294 - val_categorical_accuracy: 0.8322 - 2s/epoch - 5ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.62239
# 295/295 - 2s - loss: 0.7476 - categorical_accuracy: 0.8192 - val_loss: 0.6320 - val_categorical_accuracy: 0.8381 - 2s/epoch - 6ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.62239
# 295/295 - 1s - loss: 0.7297 - categorical_accuracy: 0.8237 - val_loss: 0.6306 - val_categorical_accuracy: 0.8305 - 1s/epoch - 4ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.62239
# 295/295 - 1s - loss: 0.7172 - categorical_accuracy: 0.8270 - val_loss: 0.6442 - val_categorical_accuracy: 0.8305 - 1s/epoch - 4ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.62239
# 295/295 - 1s - loss: 0.6983 - categorical_accuracy: 0.8353 - val_loss: 0.6316 - val_categorical_accuracy: 0.8347 - 1s/epoch - 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# 0.8389830589294434 0.1651
#
#
# nrx: 10 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.21220, saving model to t_weights_0
# 545/545 - 7s - loss: 2.6039 - categorical_accuracy: 0.1382 - val_loss: 2.2122 - val_categorical_accuracy: 0.1972 - 7s/epoch - 13ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.21220 to 1.84984, saving model to t_weights_0
# 545/545 - 4s - loss: 2.3604 - categorical_accuracy: 0.2435 - val_loss: 1.8498 - val_categorical_accuracy: 0.3592 - 4s/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.84984 to 1.58747, saving model to t_weights_0
# 545/545 - 5s - loss: 2.0460 - categorical_accuracy: 0.3588 - val_loss: 1.5875 - val_categorical_accuracy: 0.4651 - 5s/epoch - 9ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.58747 to 1.36674, saving model to t_weights_0
# 545/545 - 4s - loss: 1.7808 - categorical_accuracy: 0.4582 - val_loss: 1.3667 - val_categorical_accuracy: 0.5619 - 4s/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.36674 to 1.23820, saving model to t_weights_0
# 545/545 - 4s - loss: 1.5971 - categorical_accuracy: 0.5222 - val_loss: 1.2382 - val_categorical_accuracy: 0.6179 - 4s/epoch - 8ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.23820 to 1.17168, saving model to t_weights_0
# 545/545 - 5s - loss: 1.4704 - categorical_accuracy: 0.5810 - val_loss: 1.1717 - val_categorical_accuracy: 0.6550 - 5s/epoch - 10ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.17168 to 1.14551, saving model to t_weights_0
# 545/545 - 5s - loss: 1.3897 - categorical_accuracy: 0.6112 - val_loss: 1.1455 - val_categorical_accuracy: 0.6399 - 5s/epoch - 9ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.14551 to 1.03294, saving model to t_weights_0
# 545/545 - 4s - loss: 1.2993 - categorical_accuracy: 0.6433 - val_loss: 1.0329 - val_categorical_accuracy: 0.7060 - 4s/epoch - 8ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.03294
# 545/545 - 3s - loss: 1.2484 - categorical_accuracy: 0.6610 - val_loss: 1.0461 - val_categorical_accuracy: 0.6872 - 3s/epoch - 6ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 1.03294 to 0.91822, saving model to t_weights_0
# 545/545 - 4s - loss: 1.1955 - categorical_accuracy: 0.6809 - val_loss: 0.9182 - val_categorical_accuracy: 0.7674 - 4s/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.91822 to 0.89450, saving model to t_weights_0
# 545/545 - 4s - loss: 1.1417 - categorical_accuracy: 0.6960 - val_loss: 0.8945 - val_categorical_accuracy: 0.7578 - 4s/epoch - 7ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.89450 to 0.85882, saving model to t_weights_0
# 545/545 - 5s - loss: 1.0991 - categorical_accuracy: 0.7128 - val_loss: 0.8588 - val_categorical_accuracy: 0.7830 - 5s/epoch - 9ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.85882 to 0.85717, saving model to t_weights_0
# 545/545 - 4s - loss: 1.0680 - categorical_accuracy: 0.7175 - val_loss: 0.8572 - val_categorical_accuracy: 0.7862 - 4s/epoch - 8ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.85717 to 0.79060, saving model to t_weights_0
# 545/545 - 4s - loss: 1.0260 - categorical_accuracy: 0.7351 - val_loss: 0.7906 - val_categorical_accuracy: 0.7982 - 4s/epoch - 7ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.79060 to 0.76836, saving model to t_weights_0
# 545/545 - 5s - loss: 0.9817 - categorical_accuracy: 0.7456 - val_loss: 0.7684 - val_categorical_accuracy: 0.8032 - 5s/epoch - 9ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.76836
# 545/545 - 3s - loss: 0.9558 - categorical_accuracy: 0.7505 - val_loss: 0.7980 - val_categorical_accuracy: 0.7798 - 3s/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.76836 to 0.73995, saving model to t_weights_0
# 545/545 - 4s - loss: 0.9145 - categorical_accuracy: 0.7662 - val_loss: 0.7400 - val_categorical_accuracy: 0.8193 - 4s/epoch - 7ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.73995
# 545/545 - 2s - loss: 0.9015 - categorical_accuracy: 0.7722 - val_loss: 0.7423 - val_categorical_accuracy: 0.8101 - 2s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.73995 to 0.73219, saving model to t_weights_0
# 545/545 - 5s - loss: 0.8682 - categorical_accuracy: 0.7806 - val_loss: 0.7322 - val_categorical_accuracy: 0.8083 - 5s/epoch - 9ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.73219 to 0.69051, saving model to t_weights_0
# 545/545 - 5s - loss: 0.8544 - categorical_accuracy: 0.7841 - val_loss: 0.6905 - val_categorical_accuracy: 0.8225 - 5s/epoch - 9ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.69051 to 0.67427, saving model to t_weights_0
# 545/545 - 4s - loss: 0.8332 - categorical_accuracy: 0.7917 - val_loss: 0.6743 - val_categorical_accuracy: 0.8367 - 4s/epoch - 7ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.67427 to 0.64189, saving model to t_weights_0
# 545/545 - 5s - loss: 0.8125 - categorical_accuracy: 0.7964 - val_loss: 0.6419 - val_categorical_accuracy: 0.8390 - 5s/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.64189 to 0.63062, saving model to t_weights_0
# 545/545 - 5s - loss: 0.7875 - categorical_accuracy: 0.8053 - val_loss: 0.6306 - val_categorical_accuracy: 0.8450 - 5s/epoch - 9ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.63062 to 0.61533, saving model to t_weights_0
# 545/545 - 4s - loss: 0.7665 - categorical_accuracy: 0.8095 - val_loss: 0.6153 - val_categorical_accuracy: 0.8555 - 4s/epoch - 7ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.61533
# 545/545 - 2s - loss: 0.7545 - categorical_accuracy: 0.8111 - val_loss: 0.6160 - val_categorical_accuracy: 0.8532 - 2s/epoch - 4ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.61533
# 545/545 - 3s - loss: 0.7427 - categorical_accuracy: 0.8186 - val_loss: 0.6452 - val_categorical_accuracy: 0.8339 - 3s/epoch - 6ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.61533
# 545/545 - 2s - loss: 0.7210 - categorical_accuracy: 0.8222 - val_loss: 0.6296 - val_categorical_accuracy: 0.8463 - 2s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.61533 to 0.57071, saving model to t_weights_0
# 545/545 - 4s - loss: 0.7121 - categorical_accuracy: 0.8291 - val_loss: 0.5707 - val_categorical_accuracy: 0.8661 - 4s/epoch - 7ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.57071
# 545/545 - 2s - loss: 0.7003 - categorical_accuracy: 0.8292 - val_loss: 0.6013 - val_categorical_accuracy: 0.8477 - 2s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.57071 to 0.55897, saving model to t_weights_0
# 545/545 - 5s - loss: 0.6827 - categorical_accuracy: 0.8354 - val_loss: 0.5590 - val_categorical_accuracy: 0.8716 - 5s/epoch - 9ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.55897
# 545/545 - 2s - loss: 0.6692 - categorical_accuracy: 0.8353 - val_loss: 0.5988 - val_categorical_accuracy: 0.8606 - 2s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.55897 to 0.54918, saving model to t_weights_0
# 545/545 - 4s - loss: 0.6583 - categorical_accuracy: 0.8397 - val_loss: 0.5492 - val_categorical_accuracy: 0.8739 - 4s/epoch - 8ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.54918
# 545/545 - 2s - loss: 0.6470 - categorical_accuracy: 0.8429 - val_loss: 0.5546 - val_categorical_accuracy: 0.8688 - 2s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.54918
# 545/545 - 2s - loss: 0.6335 - categorical_accuracy: 0.8487 - val_loss: 0.5495 - val_categorical_accuracy: 0.8739 - 2s/epoch - 5ms/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 0.54918 to 0.54429, saving model to t_weights_0
# 545/545 - 5s - loss: 0.6392 - categorical_accuracy: 0.8499 - val_loss: 0.5443 - val_categorical_accuracy: 0.8748 - 5s/epoch - 9ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.54429
# 545/545 - 2s - loss: 0.6245 - categorical_accuracy: 0.8528 - val_loss: 0.5454 - val_categorical_accuracy: 0.8784 - 2s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.54429 to 0.53835, saving model to t_weights_0
# 545/545 - 4s - loss: 0.6097 - categorical_accuracy: 0.8552 - val_loss: 0.5383 - val_categorical_accuracy: 0.8725 - 4s/epoch - 7ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.53835 to 0.52055, saving model to t_weights_0
# 545/545 - 5s - loss: 0.6034 - categorical_accuracy: 0.8556 - val_loss: 0.5205 - val_categorical_accuracy: 0.8794 - 5s/epoch - 10ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.52055
# 545/545 - 2s - loss: 0.5935 - categorical_accuracy: 0.8624 - val_loss: 0.5222 - val_categorical_accuracy: 0.8830 - 2s/epoch - 4ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 0.52055 to 0.51094, saving model to t_weights_0
# 545/545 - 4s - loss: 0.5873 - categorical_accuracy: 0.8618 - val_loss: 0.5109 - val_categorical_accuracy: 0.8844 - 4s/epoch - 7ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.51094
# 545/545 - 2s - loss: 0.5795 - categorical_accuracy: 0.8647 - val_loss: 0.5153 - val_categorical_accuracy: 0.8839 - 2s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.51094
# 545/545 - 2s - loss: 0.5756 - categorical_accuracy: 0.8604 - val_loss: 0.5157 - val_categorical_accuracy: 0.8867 - 2s/epoch - 4ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.51094
# 545/545 - 3s - loss: 0.5599 - categorical_accuracy: 0.8687 - val_loss: 0.5165 - val_categorical_accuracy: 0.8826 - 3s/epoch - 6ms/step
# Epoch 44/100
#
# Epoch 44: val_loss improved from 0.51094 to 0.49229, saving model to t_weights_0
# 545/545 - 4s - loss: 0.5584 - categorical_accuracy: 0.8698 - val_loss: 0.4923 - val_categorical_accuracy: 0.8940 - 4s/epoch - 7ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.49229
# 545/545 - 2s - loss: 0.5472 - categorical_accuracy: 0.8701 - val_loss: 0.4987 - val_categorical_accuracy: 0.8917 - 2s/epoch - 4ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.49229
# 545/545 - 2s - loss: 0.5479 - categorical_accuracy: 0.8718 - val_loss: 0.4988 - val_categorical_accuracy: 0.8904 - 2s/epoch - 4ms/step
# Epoch 47/100
#
# Epoch 47: val_loss improved from 0.49229 to 0.48200, saving model to t_weights_0
# 545/545 - 5s - loss: 0.5339 - categorical_accuracy: 0.8772 - val_loss: 0.4820 - val_categorical_accuracy: 0.8931 - 5s/epoch - 9ms/step
# Epoch 48/100
#
# Epoch 48: val_loss improved from 0.48200 to 0.48048, saving model to t_weights_0
# 545/545 - 4s - loss: 0.5342 - categorical_accuracy: 0.8760 - val_loss: 0.4805 - val_categorical_accuracy: 0.8963 - 4s/epoch - 7ms/step
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.48048 to 0.47648, saving model to t_weights_0
# 545/545 - 4s - loss: 0.5245 - categorical_accuracy: 0.8787 - val_loss: 0.4765 - val_categorical_accuracy: 0.8927 - 4s/epoch - 7ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.47648
# 545/545 - 2s - loss: 0.5230 - categorical_accuracy: 0.8804 - val_loss: 0.5009 - val_categorical_accuracy: 0.8917 - 2s/epoch - 4ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.47648
# 545/545 - 3s - loss: 0.5154 - categorical_accuracy: 0.8812 - val_loss: 0.4912 - val_categorical_accuracy: 0.8876 - 3s/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: val_loss improved from 0.47648 to 0.47331, saving model to t_weights_0
# 545/545 - 5s - loss: 0.5062 - categorical_accuracy: 0.8815 - val_loss: 0.4733 - val_categorical_accuracy: 0.8986 - 5s/epoch - 10ms/step
# Epoch 53/100
#
# Epoch 53: val_loss improved from 0.47331 to 0.46787, saving model to t_weights_0
# 545/545 - 4s - loss: 0.5194 - categorical_accuracy: 0.8768 - val_loss: 0.4679 - val_categorical_accuracy: 0.9055 - 4s/epoch - 7ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.46787
# 545/545 - 3s - loss: 0.4930 - categorical_accuracy: 0.8851 - val_loss: 0.4707 - val_categorical_accuracy: 0.9050 - 3s/epoch - 6ms/step
# Epoch 55/100
#
# Epoch 55: val_loss improved from 0.46787 to 0.46452, saving model to t_weights_0
# 545/545 - 4s - loss: 0.4961 - categorical_accuracy: 0.8830 - val_loss: 0.4645 - val_categorical_accuracy: 0.9023 - 4s/epoch - 7ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.46452
# 545/545 - 2s - loss: 0.4893 - categorical_accuracy: 0.8873 - val_loss: 0.4674 - val_categorical_accuracy: 0.9018 - 2s/epoch - 4ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.46452
# 545/545 - 2s - loss: 0.4905 - categorical_accuracy: 0.8892 - val_loss: 0.4660 - val_categorical_accuracy: 0.9018 - 2s/epoch - 4ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.46452
# 545/545 - 2s - loss: 0.4789 - categorical_accuracy: 0.8896 - val_loss: 0.4770 - val_categorical_accuracy: 0.9037 - 2s/epoch - 4ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.46452
# 545/545 - 3s - loss: 0.4759 - categorical_accuracy: 0.8916 - val_loss: 0.4791 - val_categorical_accuracy: 0.8936 - 3s/epoch - 6ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.46452
# 545/545 - 2s - loss: 0.4766 - categorical_accuracy: 0.8921 - val_loss: 0.4800 - val_categorical_accuracy: 0.9014 - 2s/epoch - 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# 0.9036697149276733 0.5122
#
#
# nrx: 15 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.17129, saving model to t_weights_0
# 785/785 - 8s - loss: 2.5919 - categorical_accuracy: 0.1474 - val_loss: 2.1713 - val_categorical_accuracy: 0.2191 - 8s/epoch - 10ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.17129 to 1.86181, saving model to t_weights_0
# 785/785 - 6s - loss: 2.3277 - categorical_accuracy: 0.2625 - val_loss: 1.8618 - val_categorical_accuracy: 0.3404 - 6s/epoch - 8ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.86181 to 1.53732, saving model to t_weights_0
# 785/785 - 5s - loss: 1.9954 - categorical_accuracy: 0.3850 - val_loss: 1.5373 - val_categorical_accuracy: 0.4895 - 5s/epoch - 7ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.53732 to 1.36041, saving model to t_weights_0
# 785/785 - 5s - loss: 1.6934 - categorical_accuracy: 0.4967 - val_loss: 1.3604 - val_categorical_accuracy: 0.5662 - 5s/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.36041 to 1.16153, saving model to t_weights_0
# 785/785 - 5s - loss: 1.4949 - categorical_accuracy: 0.5711 - val_loss: 1.1615 - val_categorical_accuracy: 0.6389 - 5s/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.16153 to 1.06928, saving model to t_weights_0
# 785/785 - 5s - loss: 1.3739 - categorical_accuracy: 0.6204 - val_loss: 1.0693 - val_categorical_accuracy: 0.6796 - 5s/epoch - 6ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.06928 to 1.05305, saving model to t_weights_0
# 785/785 - 6s - loss: 1.2693 - categorical_accuracy: 0.6564 - val_loss: 1.0531 - val_categorical_accuracy: 0.6691 - 6s/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.05305 to 0.93800, saving model to t_weights_0
# 785/785 - 5s - loss: 1.1952 - categorical_accuracy: 0.6794 - val_loss: 0.9380 - val_categorical_accuracy: 0.7328 - 5s/epoch - 6ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.93800 to 0.86484, saving model to t_weights_0
# 785/785 - 5s - loss: 1.1247 - categorical_accuracy: 0.7045 - val_loss: 0.8648 - val_categorical_accuracy: 0.7471 - 5s/epoch - 7ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.86484 to 0.83021, saving model to t_weights_0
# 785/785 - 6s - loss: 1.0720 - categorical_accuracy: 0.7190 - val_loss: 0.8302 - val_categorical_accuracy: 0.7656 - 6s/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.83021 to 0.78467, saving model to t_weights_0
# 785/785 - 5s - loss: 1.0204 - categorical_accuracy: 0.7349 - val_loss: 0.7847 - val_categorical_accuracy: 0.7828 - 5s/epoch - 6ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.78467
# 785/785 - 4s - loss: 0.9843 - categorical_accuracy: 0.7457 - val_loss: 0.7852 - val_categorical_accuracy: 0.7780 - 4s/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.78467 to 0.75109, saving model to t_weights_0
# 785/785 - 5s - loss: 0.9389 - categorical_accuracy: 0.7600 - val_loss: 0.7511 - val_categorical_accuracy: 0.7914 - 5s/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.75109 to 0.69756, saving model to t_weights_0
# 785/785 - 5s - loss: 0.9139 - categorical_accuracy: 0.7643 - val_loss: 0.6976 - val_categorical_accuracy: 0.8131 - 5s/epoch - 7ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.69756 to 0.66749, saving model to t_weights_0
# 785/785 - 6s - loss: 0.8747 - categorical_accuracy: 0.7818 - val_loss: 0.6675 - val_categorical_accuracy: 0.8207 - 6s/epoch - 7ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.66749 to 0.63868, saving model to t_weights_0
# 785/785 - 5s - loss: 0.8537 - categorical_accuracy: 0.7834 - val_loss: 0.6387 - val_categorical_accuracy: 0.8258 - 5s/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.63868 to 0.62254, saving model to t_weights_0
# 785/785 - 6s - loss: 0.8294 - categorical_accuracy: 0.7900 - val_loss: 0.6225 - val_categorical_accuracy: 0.8347 - 6s/epoch - 8ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.62254 to 0.61848, saving model to t_weights_0
# 785/785 - 5s - loss: 0.8049 - categorical_accuracy: 0.7995 - val_loss: 0.6185 - val_categorical_accuracy: 0.8404 - 5s/epoch - 6ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.61848 to 0.59949, saving model to t_weights_0
# 785/785 - 5s - loss: 0.7926 - categorical_accuracy: 0.8039 - val_loss: 0.5995 - val_categorical_accuracy: 0.8401 - 5s/epoch - 6ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.59949 to 0.56806, saving model to t_weights_0
# 785/785 - 6s - loss: 0.7732 - categorical_accuracy: 0.8109 - val_loss: 0.5681 - val_categorical_accuracy: 0.8506 - 6s/epoch - 8ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.56806 to 0.56133, saving model to t_weights_0
# 785/785 - 5s - loss: 0.7604 - categorical_accuracy: 0.8133 - val_loss: 0.5613 - val_categorical_accuracy: 0.8545 - 5s/epoch - 6ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.56133 to 0.55587, saving model to t_weights_0
# 785/785 - 6s - loss: 0.7424 - categorical_accuracy: 0.8190 - val_loss: 0.5559 - val_categorical_accuracy: 0.8561 - 6s/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.55587
# 785/785 - 3s - loss: 0.7275 - categorical_accuracy: 0.8229 - val_loss: 0.5559 - val_categorical_accuracy: 0.8541 - 3s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.55587
# 785/785 - 4s - loss: 0.7134 - categorical_accuracy: 0.8279 - val_loss: 0.5602 - val_categorical_accuracy: 0.8535 - 4s/epoch - 5ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.55587 to 0.54328, saving model to t_weights_0
# 785/785 - 6s - loss: 0.7052 - categorical_accuracy: 0.8283 - val_loss: 0.5433 - val_categorical_accuracy: 0.8656 - 6s/epoch - 8ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.54328
# 785/785 - 3s - loss: 0.6867 - categorical_accuracy: 0.8331 - val_loss: 0.5543 - val_categorical_accuracy: 0.8605 - 3s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.54328 to 0.53197, saving model to t_weights_0
# 785/785 - 5s - loss: 0.6871 - categorical_accuracy: 0.8312 - val_loss: 0.5320 - val_categorical_accuracy: 0.8634 - 5s/epoch - 6ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.53197 to 0.50159, saving model to t_weights_0
# 785/785 - 6s - loss: 0.6689 - categorical_accuracy: 0.8373 - val_loss: 0.5016 - val_categorical_accuracy: 0.8764 - 6s/epoch - 8ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.50159
# 785/785 - 3s - loss: 0.6680 - categorical_accuracy: 0.8380 - val_loss: 0.5162 - val_categorical_accuracy: 0.8694 - 3s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.50159
# 785/785 - 3s - loss: 0.6503 - categorical_accuracy: 0.8447 - val_loss: 0.5138 - val_categorical_accuracy: 0.8720 - 3s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.50159 to 0.49476, saving model to t_weights_0
# 785/785 - 6s - loss: 0.6501 - categorical_accuracy: 0.8445 - val_loss: 0.4948 - val_categorical_accuracy: 0.8780 - 6s/epoch - 8ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.49476
# 785/785 - 3s - loss: 0.6373 - categorical_accuracy: 0.8483 - val_loss: 0.4972 - val_categorical_accuracy: 0.8780 - 3s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.49476
# 785/785 - 3s - loss: 0.6317 - categorical_accuracy: 0.8500 - val_loss: 0.4967 - val_categorical_accuracy: 0.8809 - 3s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.49476 to 0.47047, saving model to t_weights_0
# 785/785 - 5s - loss: 0.6167 - categorical_accuracy: 0.8544 - val_loss: 0.4705 - val_categorical_accuracy: 0.8882 - 5s/epoch - 7ms/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 0.47047 to 0.46498, saving model to t_weights_0
# 785/785 - 6s - loss: 0.6072 - categorical_accuracy: 0.8578 - val_loss: 0.4650 - val_categorical_accuracy: 0.8844 - 6s/epoch - 7ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.46498
# 785/785 - 3s - loss: 0.6128 - categorical_accuracy: 0.8526 - val_loss: 0.5059 - val_categorical_accuracy: 0.8656 - 3s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.46498
# 785/785 - 3s - loss: 0.6064 - categorical_accuracy: 0.8551 - val_loss: 0.4739 - val_categorical_accuracy: 0.8825 - 3s/epoch - 4ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.46498 to 0.45809, saving model to t_weights_0
# 785/785 - 6s - loss: 0.5913 - categorical_accuracy: 0.8618 - val_loss: 0.4581 - val_categorical_accuracy: 0.8844 - 6s/epoch - 7ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.45809
# 785/785 - 3s - loss: 0.5922 - categorical_accuracy: 0.8613 - val_loss: 0.4617 - val_categorical_accuracy: 0.8850 - 3s/epoch - 4ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.45809
# 785/785 - 3s - loss: 0.5848 - categorical_accuracy: 0.8605 - val_loss: 0.4691 - val_categorical_accuracy: 0.8844 - 3s/epoch - 4ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.45809 to 0.45010, saving model to t_weights_0
# 785/785 - 6s - loss: 0.5779 - categorical_accuracy: 0.8656 - val_loss: 0.4501 - val_categorical_accuracy: 0.8898 - 6s/epoch - 8ms/step
# Epoch 42/100
#
# Epoch 42: val_loss improved from 0.45010 to 0.43645, saving model to t_weights_0
# 785/785 - 5s - loss: 0.5693 - categorical_accuracy: 0.8670 - val_loss: 0.4364 - val_categorical_accuracy: 0.8914 - 5s/epoch - 6ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.43645
# 785/785 - 3s - loss: 0.5641 - categorical_accuracy: 0.8681 - val_loss: 0.4516 - val_categorical_accuracy: 0.8924 - 3s/epoch - 4ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.43645
# 785/785 - 4s - loss: 0.5586 - categorical_accuracy: 0.8702 - val_loss: 0.4432 - val_categorical_accuracy: 0.8917 - 4s/epoch - 5ms/step
# Epoch 45/100
#
# Epoch 45: val_loss improved from 0.43645 to 0.42879, saving model to t_weights_0
# 785/785 - 5s - loss: 0.5567 - categorical_accuracy: 0.8719 - val_loss: 0.4288 - val_categorical_accuracy: 0.8968 - 5s/epoch - 7ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.42879
# 785/785 - 3s - loss: 0.5526 - categorical_accuracy: 0.8713 - val_loss: 0.4306 - val_categorical_accuracy: 0.8990 - 3s/epoch - 4ms/step
# Epoch 47/100
#
# Epoch 47: val_loss improved from 0.42879 to 0.42850, saving model to t_weights_0
# 785/785 - 6s - loss: 0.5485 - categorical_accuracy: 0.8728 - val_loss: 0.4285 - val_categorical_accuracy: 0.8965 - 6s/epoch - 7ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.42850
# 785/785 - 3s - loss: 0.5471 - categorical_accuracy: 0.8721 - val_loss: 0.4466 - val_categorical_accuracy: 0.8898 - 3s/epoch - 4ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.42850
# 785/785 - 3s - loss: 0.5403 - categorical_accuracy: 0.8754 - val_loss: 0.4333 - val_categorical_accuracy: 0.9022 - 3s/epoch - 4ms/step
# Epoch 50/100
#
# Epoch 50: val_loss improved from 0.42850 to 0.42263, saving model to t_weights_0
# 785/785 - 6s - loss: 0.5321 - categorical_accuracy: 0.8771 - val_loss: 0.4226 - val_categorical_accuracy: 0.9025 - 6s/epoch - 8ms/step
# Epoch 51/100
#
# Epoch 51: val_loss improved from 0.42263 to 0.41559, saving model to t_weights_0
# 785/785 - 5s - loss: 0.5237 - categorical_accuracy: 0.8818 - val_loss: 0.4156 - val_categorical_accuracy: 0.9041 - 5s/epoch - 7ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.41559
# 785/785 - 3s - loss: 0.5172 - categorical_accuracy: 0.8816 - val_loss: 0.4346 - val_categorical_accuracy: 0.9010 - 3s/epoch - 4ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.41559
# 785/785 - 4s - loss: 0.5223 - categorical_accuracy: 0.8795 - val_loss: 0.4878 - val_categorical_accuracy: 0.8701 - 4s/epoch - 5ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.41559
# 785/785 - 3s - loss: 0.5146 - categorical_accuracy: 0.8820 - val_loss: 0.4417 - val_categorical_accuracy: 0.8968 - 3s/epoch - 4ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.41559
# 785/785 - 3s - loss: 0.5162 - categorical_accuracy: 0.8816 - val_loss: 0.4166 - val_categorical_accuracy: 0.9013 - 3s/epoch - 4ms/step
# Epoch 56/100
#
# Epoch 56: val_loss improved from 0.41559 to 0.40532, saving model to t_weights_0
# 785/785 - 5s - loss: 0.5130 - categorical_accuracy: 0.8817 - val_loss: 0.4053 - val_categorical_accuracy: 0.9096 - 5s/epoch - 6ms/step
# Epoch 57/100
#
# Epoch 57: val_loss improved from 0.40532 to 0.40006, saving model to t_weights_0
# 785/785 - 6s - loss: 0.5055 - categorical_accuracy: 0.8849 - val_loss: 0.4001 - val_categorical_accuracy: 0.9080 - 6s/epoch - 7ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.40006
# 785/785 - 3s - loss: 0.4997 - categorical_accuracy: 0.8849 - val_loss: 0.4235 - val_categorical_accuracy: 0.9051 - 3s/epoch - 4ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.40006
# 785/785 - 3s - loss: 0.5001 - categorical_accuracy: 0.8863 - val_loss: 0.4178 - val_categorical_accuracy: 0.8981 - 3s/epoch - 4ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.40006
# 785/785 - 4s - loss: 0.4993 - categorical_accuracy: 0.8850 - val_loss: 0.4089 - val_categorical_accuracy: 0.9041 - 4s/epoch - 6ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.40006
# 785/785 - 3s - loss: 0.4908 - categorical_accuracy: 0.8877 - val_loss: 0.4067 - val_categorical_accuracy: 0.9073 - 3s/epoch - 4ms/step
# Epoch 62/100
#
# Epoch 62: val_loss improved from 0.40006 to 0.39477, saving model to t_weights_0
# 785/785 - 6s - loss: 0.4956 - categorical_accuracy: 0.8867 - val_loss: 0.3948 - val_categorical_accuracy: 0.9118 - 6s/epoch - 8ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.39477
# 785/785 - 4s - loss: 0.4857 - categorical_accuracy: 0.8891 - val_loss: 0.3996 - val_categorical_accuracy: 0.9076 - 4s/epoch - 5ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.39477
# 785/785 - 3s - loss: 0.4782 - categorical_accuracy: 0.8924 - val_loss: 0.3961 - val_categorical_accuracy: 0.9092 - 3s/epoch - 4ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.39477
# 785/785 - 3s - loss: 0.4850 - categorical_accuracy: 0.8879 - val_loss: 0.3997 - val_categorical_accuracy: 0.9076 - 3s/epoch - 4ms/step
# Epoch 66/100
#
# Epoch 66: val_loss improved from 0.39477 to 0.39328, saving model to t_weights_0
# 785/785 - 6s - loss: 0.4700 - categorical_accuracy: 0.8939 - val_loss: 0.3933 - val_categorical_accuracy: 0.9108 - 6s/epoch - 7ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.39328
# 785/785 - 3s - loss: 0.4821 - categorical_accuracy: 0.8914 - val_loss: 0.4007 - val_categorical_accuracy: 0.9089 - 3s/epoch - 4ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.39328
# 785/785 - 3s - loss: 0.4786 - categorical_accuracy: 0.8911 - val_loss: 0.3964 - val_categorical_accuracy: 0.9162 - 3s/epoch - 4ms/step
# Epoch 69/100
#
# Epoch 69: val_loss improved from 0.39328 to 0.38845, saving model to t_weights_0
# 785/785 - 5s - loss: 0.4712 - categorical_accuracy: 0.8946 - val_loss: 0.3885 - val_categorical_accuracy: 0.9143 - 5s/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.38845
# 785/785 - 4s - loss: 0.4707 - categorical_accuracy: 0.8941 - val_loss: 0.3962 - val_categorical_accuracy: 0.9124 - 4s/epoch - 5ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.38845
# 785/785 - 3s - loss: 0.4639 - categorical_accuracy: 0.8946 - val_loss: 0.4221 - val_categorical_accuracy: 0.8997 - 3s/epoch - 4ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.38845
# 785/785 - 3s - loss: 0.4653 - categorical_accuracy: 0.8953 - val_loss: 0.4053 - val_categorical_accuracy: 0.9099 - 3s/epoch - 4ms/step
# Epoch 73/100
#
# Epoch 73: val_loss improved from 0.38845 to 0.38228, saving model to t_weights_0
# 785/785 - 6s - loss: 0.4622 - categorical_accuracy: 0.8965 - val_loss: 0.3823 - val_categorical_accuracy: 0.9127 - 6s/epoch - 8ms/step
# Epoch 74/100
#
# Epoch 74: val_loss improved from 0.38228 to 0.37799, saving model to t_weights_0
# 785/785 - 5s - loss: 0.4591 - categorical_accuracy: 0.8963 - val_loss: 0.3780 - val_categorical_accuracy: 0.9175 - 5s/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: val_loss improved from 0.37799 to 0.37122, saving model to t_weights_0
# 785/785 - 5s - loss: 0.4495 - categorical_accuracy: 0.8995 - val_loss: 0.3712 - val_categorical_accuracy: 0.9236 - 5s/epoch - 6ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.37122
# 785/785 - 4s - loss: 0.4645 - categorical_accuracy: 0.8939 - val_loss: 0.3909 - val_categorical_accuracy: 0.9118 - 4s/epoch - 5ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.37122
# 785/785 - 3s - loss: 0.4582 - categorical_accuracy: 0.8964 - val_loss: 0.3877 - val_categorical_accuracy: 0.9150 - 3s/epoch - 4ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.37122
# 785/785 - 3s - loss: 0.4510 - categorical_accuracy: 0.9012 - val_loss: 0.3769 - val_categorical_accuracy: 0.9226 - 3s/epoch - 4ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.37122
# 785/785 - 3s - loss: 0.4543 - categorical_accuracy: 0.8975 - val_loss: 0.3951 - val_categorical_accuracy: 0.9159 - 3s/epoch - 4ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.37122
# ...
# Epoch 81/100
#
# Epoch 81: val_loss improved from 0.38177 to 0.37305, saving model to t_weights_0
# 1030/1030 - 8s - loss: 0.4195 - categorical_accuracy: 0.9082 - val_loss: 0.3731 - val_categorical_accuracy: 0.9269 - 8s/epoch - 7ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.37305
# 1030/1030 - 5s - loss: 0.4139 - categorical_accuracy: 0.9113 - val_loss: 0.3944 - val_categorical_accuracy: 0.9147 - 5s/epoch - 5ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.37305
# 1030/1030 - 6s - loss: 0.4085 - categorical_accuracy: 0.9133 - val_loss: 0.3854 - val_categorical_accuracy: 0.9174 - 6s/epoch - 5ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.37305
# 1030/1030 - 6s - loss: 0.4084 - categorical_accuracy: 0.9129 - val_loss: 0.3938 - val_categorical_accuracy: 0.9160 - 6s/epoch - 5ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.37305
# 1030/1030 - 5s - loss: 0.4036 - categorical_accuracy: 0.9128 - val_loss: 0.3893 - val_categorical_accuracy: 0.9179 - 5s/epoch - 5ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.37305
# 1030/1030 - 6s - loss: 0.4090 - categorical_accuracy: 0.9120 - val_loss: 0.3828 - val_categorical_accuracy: 0.9208 - 6s/epoch - 6ms/step
# 307/307 [==============================] - 1s 3ms/step
# 0.9300461411476135 0.5864285714285714
#
#
# nrx: 25 - real: 4
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.13927, saving model to t_weights_0
# 1260/1260 - 11s - loss: 2.4097 - categorical_accuracy: 0.1622 - val_loss: 2.1393 - val_categorical_accuracy: 0.2400 - 11s/epoch - 9ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.13927 to 1.73519, saving model to t_weights_0
# 1260/1260 - 8s - loss: 2.1237 - categorical_accuracy: 0.2978 - val_loss: 1.7352 - val_categorical_accuracy: 0.4189 - 8s/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.73519 to 1.46455, saving model to t_weights_0
# 1260/1260 - 8s - loss: 1.7569 - categorical_accuracy: 0.4445 - val_loss: 1.4646 - val_categorical_accuracy: 0.5263 - 8s/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.46455 to 1.23478, saving model to t_weights_0
# 1260/1260 - 9s - loss: 1.5080 - categorical_accuracy: 0.5376 - val_loss: 1.2348 - val_categorical_accuracy: 0.6129 - 9s/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.23478 to 1.13311, saving model to t_weights_0
# 1260/1260 - 8s - loss: 1.3318 - categorical_accuracy: 0.5996 - val_loss: 1.1331 - val_categorical_accuracy: 0.6474 - 8s/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.13311 to 1.01547, saving model to t_weights_0
# 1260/1260 - 8s - loss: 1.2126 - categorical_accuracy: 0.6421 - val_loss: 1.0155 - val_categorical_accuracy: 0.6893 - 8s/epoch - 6ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.01547 to 0.94916, saving model to t_weights_0
# 1260/1260 - 9s - loss: 1.1169 - categorical_accuracy: 0.6727 - val_loss: 0.9492 - val_categorical_accuracy: 0.7151 - 9s/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.94916 to 0.89548, saving model to t_weights_0
# 1260/1260 - 9s - loss: 1.0542 - categorical_accuracy: 0.6933 - val_loss: 0.8955 - val_categorical_accuracy: 0.7282 - 9s/epoch - 7ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.89548 to 0.83005, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.9932 - categorical_accuracy: 0.7153 - val_loss: 0.8301 - val_categorical_accuracy: 0.7508 - 8s/epoch - 6ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.83005 to 0.80247, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.9514 - categorical_accuracy: 0.7304 - val_loss: 0.8025 - val_categorical_accuracy: 0.7632 - 9s/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.80247 to 0.75787, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.9084 - categorical_accuracy: 0.7444 - val_loss: 0.7579 - val_categorical_accuracy: 0.7844 - 9s/epoch - 7ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.75787 to 0.74878, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.8769 - categorical_accuracy: 0.7570 - val_loss: 0.7488 - val_categorical_accuracy: 0.7800 - 8s/epoch - 6ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.74878 to 0.70418, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.8442 - categorical_accuracy: 0.7679 - val_loss: 0.7042 - val_categorical_accuracy: 0.7985 - 9s/epoch - 7ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.70418 to 0.69548, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.8196 - categorical_accuracy: 0.7740 - val_loss: 0.6955 - val_categorical_accuracy: 0.8050 - 8s/epoch - 7ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.69548 to 0.66873, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.7949 - categorical_accuracy: 0.7838 - val_loss: 0.6687 - val_categorical_accuracy: 0.8096 - 8s/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.66873
# 1260/1260 - 7s - loss: 0.7671 - categorical_accuracy: 0.7920 - val_loss: 0.6920 - val_categorical_accuracy: 0.8015 - 7s/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.66873 to 0.63854, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.7520 - categorical_accuracy: 0.7977 - val_loss: 0.6385 - val_categorical_accuracy: 0.8259 - 8s/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.63854 to 0.62710, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.7295 - categorical_accuracy: 0.8055 - val_loss: 0.6271 - val_categorical_accuracy: 0.8259 - 8s/epoch - 7ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.62710 to 0.62663, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.7205 - categorical_accuracy: 0.8085 - val_loss: 0.6266 - val_categorical_accuracy: 0.8291 - 8s/epoch - 7ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.62663 to 0.61953, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.7040 - categorical_accuracy: 0.8154 - val_loss: 0.6195 - val_categorical_accuracy: 0.8299 - 8s/epoch - 6ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.61953
# 1260/1260 - 7s - loss: 0.6910 - categorical_accuracy: 0.8186 - val_loss: 0.6393 - val_categorical_accuracy: 0.8259 - 7s/epoch - 5ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.61953 to 0.57178, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.6702 - categorical_accuracy: 0.8258 - val_loss: 0.5718 - val_categorical_accuracy: 0.8487 - 8s/epoch - 7ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.57178
# 1260/1260 - 6s - loss: 0.6607 - categorical_accuracy: 0.8303 - val_loss: 0.5735 - val_categorical_accuracy: 0.8507 - 6s/epoch - 5ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.57178 to 0.55773, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.6443 - categorical_accuracy: 0.8342 - val_loss: 0.5577 - val_categorical_accuracy: 0.8594 - 8s/epoch - 7ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.55773 to 0.55209, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.6449 - categorical_accuracy: 0.8341 - val_loss: 0.5521 - val_categorical_accuracy: 0.8588 - 8s/epoch - 6ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.55209 to 0.54002, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.6310 - categorical_accuracy: 0.8401 - val_loss: 0.5400 - val_categorical_accuracy: 0.8604 - 9s/epoch - 7ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.54002 to 0.53221, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.6179 - categorical_accuracy: 0.8467 - val_loss: 0.5322 - val_categorical_accuracy: 0.8644 - 8s/epoch - 7ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.53221
# 1260/1260 - 6s - loss: 0.6035 - categorical_accuracy: 0.8475 - val_loss: 0.5472 - val_categorical_accuracy: 0.8567 - 6s/epoch - 5ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.53221 to 0.53077, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.6029 - categorical_accuracy: 0.8488 - val_loss: 0.5308 - val_categorical_accuracy: 0.8674 - 9s/epoch - 7ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.53077 to 0.52129, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.5928 - categorical_accuracy: 0.8516 - val_loss: 0.5213 - val_categorical_accuracy: 0.8712 - 9s/epoch - 7ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.52129
# 1260/1260 - 6s - loss: 0.5843 - categorical_accuracy: 0.8533 - val_loss: 0.5228 - val_categorical_accuracy: 0.8717 - 6s/epoch - 5ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.52129 to 0.51042, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.5802 - categorical_accuracy: 0.8558 - val_loss: 0.5104 - val_categorical_accuracy: 0.8737 - 9s/epoch - 7ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.51042 to 0.48898, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.5713 - categorical_accuracy: 0.8583 - val_loss: 0.4890 - val_categorical_accuracy: 0.8799 - 8s/epoch - 6ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.48898 to 0.48257, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.5632 - categorical_accuracy: 0.8611 - val_loss: 0.4826 - val_categorical_accuracy: 0.8829 - 9s/epoch - 7ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.48257
# 1260/1260 - 7s - loss: 0.5491 - categorical_accuracy: 0.8676 - val_loss: 0.4918 - val_categorical_accuracy: 0.8797 - 7s/epoch - 6ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.48257 to 0.48098, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.5482 - categorical_accuracy: 0.8652 - val_loss: 0.4810 - val_categorical_accuracy: 0.8821 - 8s/epoch - 6ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.48098 to 0.46702, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.5396 - categorical_accuracy: 0.8684 - val_loss: 0.4670 - val_categorical_accuracy: 0.8890 - 9s/epoch - 7ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.46702
# 1260/1260 - 7s - loss: 0.5291 - categorical_accuracy: 0.8710 - val_loss: 0.4781 - val_categorical_accuracy: 0.8827 - 7s/epoch - 5ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.46702
# 1260/1260 - 6s - loss: 0.5276 - categorical_accuracy: 0.8710 - val_loss: 0.5074 - val_categorical_accuracy: 0.8743 - 6s/epoch - 5ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 0.46702 to 0.44718, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.5234 - categorical_accuracy: 0.8742 - val_loss: 0.4472 - val_categorical_accuracy: 0.8934 - 9s/epoch - 7ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.44718
# 1260/1260 - 6s - loss: 0.5148 - categorical_accuracy: 0.8752 - val_loss: 0.4587 - val_categorical_accuracy: 0.8884 - 6s/epoch - 5ms/step
# Epoch 42/100
#
# Epoch 42: val_loss improved from 0.44718 to 0.44693, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.5079 - categorical_accuracy: 0.8769 - val_loss: 0.4469 - val_categorical_accuracy: 0.8972 - 9s/epoch - 7ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.44693
# 1260/1260 - 6s - loss: 0.5040 - categorical_accuracy: 0.8780 - val_loss: 0.4972 - val_categorical_accuracy: 0.8761 - 6s/epoch - 5ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.44693
# 1260/1260 - 7s - loss: 0.4991 - categorical_accuracy: 0.8795 - val_loss: 0.4703 - val_categorical_accuracy: 0.8870 - 7s/epoch - 5ms/step
# Epoch 45/100
#
# Epoch 45: val_loss improved from 0.44693 to 0.42662, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.4962 - categorical_accuracy: 0.8812 - val_loss: 0.4266 - val_categorical_accuracy: 0.9033 - 9s/epoch - 7ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.42662
# 1260/1260 - 6s - loss: 0.4861 - categorical_accuracy: 0.8852 - val_loss: 0.4526 - val_categorical_accuracy: 0.8930 - 6s/epoch - 5ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.42662
# 1260/1260 - 7s - loss: 0.4838 - categorical_accuracy: 0.8837 - val_loss: 0.4330 - val_categorical_accuracy: 0.9001 - 7s/epoch - 5ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.42662
# 1260/1260 - 6s - loss: 0.4773 - categorical_accuracy: 0.8878 - val_loss: 0.4438 - val_categorical_accuracy: 0.8918 - 6s/epoch - 5ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.42662
# 1260/1260 - 7s - loss: 0.4732 - categorical_accuracy: 0.8878 - val_loss: 0.4532 - val_categorical_accuracy: 0.8868 - 7s/epoch - 5ms/step
# Epoch 50/100
#
# Epoch 50: val_loss improved from 0.42662 to 0.42454, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.4688 - categorical_accuracy: 0.8893 - val_loss: 0.4245 - val_categorical_accuracy: 0.9009 - 8s/epoch - 6ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.42454
# 1260/1260 - 7s - loss: 0.4660 - categorical_accuracy: 0.8905 - val_loss: 0.4363 - val_categorical_accuracy: 0.8954 - 7s/epoch - 5ms/step
# Epoch 52/100
#
# Epoch 52: val_loss improved from 0.42454 to 0.41466, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.4654 - categorical_accuracy: 0.8920 - val_loss: 0.4147 - val_categorical_accuracy: 0.9047 - 8s/epoch - 6ms/step
# Epoch 53/100
#
# Epoch 53: val_loss improved from 0.41466 to 0.41020, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.4565 - categorical_accuracy: 0.8943 - val_loss: 0.4102 - val_categorical_accuracy: 0.9039 - 8s/epoch - 7ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.41020
# 1260/1260 - 7s - loss: 0.4600 - categorical_accuracy: 0.8911 - val_loss: 0.4144 - val_categorical_accuracy: 0.9075 - 7s/epoch - 5ms/step
# Epoch 55/100
#
# Epoch 55: val_loss improved from 0.41020 to 0.39454, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.4500 - categorical_accuracy: 0.8950 - val_loss: 0.3945 - val_categorical_accuracy: 0.9105 - 8s/epoch - 6ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.39454
# 1260/1260 - 7s - loss: 0.4456 - categorical_accuracy: 0.8963 - val_loss: 0.4337 - val_categorical_accuracy: 0.8984 - 7s/epoch - 5ms/step
# Epoch 57/100
#
# Epoch 57: val_loss improved from 0.39454 to 0.39236, saving model to t_weights_0
# 1260/1260 - 9s - loss: 0.4416 - categorical_accuracy: 0.8966 - val_loss: 0.3924 - val_categorical_accuracy: 0.9172 - 9s/epoch - 7ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.39236
# 1260/1260 - 6s - loss: 0.4395 - categorical_accuracy: 0.8987 - val_loss: 0.3986 - val_categorical_accuracy: 0.9085 - 6s/epoch - 5ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.39236
# 1260/1260 - 6s - loss: 0.4392 - categorical_accuracy: 0.8978 - val_loss: 0.4095 - val_categorical_accuracy: 0.9073 - 6s/epoch - 5ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.39236
# 1260/1260 - 7s - loss: 0.4285 - categorical_accuracy: 0.9033 - val_loss: 0.4028 - val_categorical_accuracy: 0.9101 - 7s/epoch - 5ms/step
# Epoch 61/100
#
# Epoch 61: val_loss improved from 0.39236 to 0.37975, saving model to t_weights_0
# 1260/1260 - 8s - loss: 0.4281 - categorical_accuracy: 0.9020 - val_loss: 0.3798 - val_categorical_accuracy: 0.9140 - 8s/epoch - 7ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.37975
# 1260/1260 - 6s - loss: 0.4234 - categorical_accuracy: 0.9010 - val_loss: 0.3996 - val_categorical_accuracy: 0.9130 - 6s/epoch - 5ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.37975
# 1260/1260 - 7s - loss: 0.4256 - categorical_accuracy: 0.9019 - val_loss: 0.3901 - val_categorical_accuracy: 0.9188 - 7s/epoch - 5ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.37975
# 1260/1260 - 6s - loss: 0.4201 - categorical_accuracy: 0.9040 - val_loss: 0.3991 - val_categorical_accuracy: 0.9117 - 6s/epoch - 5ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.37975
# 1260/1260 - 7s - loss: 0.4201 - categorical_accuracy: 0.9037 - val_loss: 0.3978 - val_categorical_accuracy: 0.9109 - 7s/epoch - 5ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.37975
# 1260/1260 - 6s - loss: 0.4149 - categorical_accuracy: 0.9047 - val_loss: 0.3878 - val_categorical_accuracy: 0.9128 - 6s/epoch - 5ms/step
# 307/307 [==============================] - 1s 3ms/step
# 0.9199920296669006 0.6038775510204082

# %%
matplotlib.rcParams['figure.dpi'] = 100
plt.errorbar(np.array(nrx_list)+1,np.mean(smTest_results,0),np.std(smTest_results,0),capsize=4)
plt.errorbar(np.array(nrx_list)+1,np.mean(dfTest_results,0),np.std(dfTest_results,0),capsize=4)
plt.legend(['Same Rx(s)','Diff. Rx'])
plt.xlabel('N Train Rx')
plt.ylabel('Class. Accuracy')
#plt.xticks(range(0,len(nrx_list),2))
plt.grid()
print(np.mean(dfTest_results,0).tolist())
# Out:
# [0.12808367346938776, 0.17811387755102043, 0.3220220408163265, 0.4850428571428571, 0.5760232653061224, 0.6175644897959184]

# %%
# !cp -r /content/weights /content/drive/MyDrive/cnn_attention
