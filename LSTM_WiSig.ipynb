# %% [markdown]
# ## Utilities Functions

# %%
import numpy as np
import pickle
import os
import os.path




def load_from_full_dataset(full_dataset_path, capture_date,rx_name,prefix=None):
    src=full_dataset_path

    if prefix is None: 
        dataset_path = '{}pkl_wifi_{}/dataset_{}_node{}.pkl'.format(src,capture_date,capture_date,rx_name)
    else:
        dataset_path = '{}pkl_wifi_{}_{}/dataset_{}_node{}.pkl'.format(src,prefix,capture_date,capture_date,rx_name)
   
    if os.path.isfile(dataset_path) :
        with open(dataset_path,'rb') as f:
            dataset = pickle.load(f)
    else:
            dataset = None
#             print('Not Found')
#             print(dataset_path)
    return dataset


def load_compact_pkl_dataset(dataset_path,dataset_name):
    with open(dataset_path+dataset_name+'.pkl','rb') as f:
        dataset = pickle.load(f)
    return dataset


def shuffle(vec1,vec2,seed = 0):
    np.random.seed(0)
#     print(vec1.shape[0],vec2.shape[0])
    shfl_indx = np.arange(vec1.shape[0])
    np.random.shuffle(shfl_indx)
    shfl_indx = shfl_indx.astype('int')
    vec1 = vec1[shfl_indx]
    vec2 = np.copy(vec2[shfl_indx])
    return vec1,vec2


def norm(sig_u):
    if len(sig_u.shape)==3:
        pwr = np.sqrt(np.mean(np.sum(sig_u**2,axis = -1),axis = -1))
        sig_u = sig_u/pwr[:,None,None]
    if len(sig_u.shape)==2:
        pwr =  np.sqrt(np.mean(np.sum(sig_u**2,axis = -1),axis = -1))
        sig_u = sig_u/pwr
    # print(sig_u.shape)
    return sig_u

def split3(vec,n1,n2):
    vec1 = vec[0:n1]
    vec2 = vec[n1:n1+n2]
    vec3 = vec[n1+n2:]
    return vec3,vec1,vec2

def split_set3(st,f1,f2):
    [sig,txid] = st

    n_samples  = sig.shape[0]
    n1 = int(f1*n_samples)
    n2 = int(f2*n_samples)

    sig1,sig2,sig3 = split3(sig,n1,n2)
    txid1,txid2,txid3 = split3(txid,n1,n2)
    st1 = [sig1,txid1]
    st2 = [sig2,txid2]
    st3 = [sig3,txid3]
    return st1,st2,st3 

def get_node_indices(tx_name_list,node_name_list):
    op_list = []
    for tx in tx_name_list:
        if tx in node_name_list:
            op_list.append(node_name_list.index(tx))
        else:
            op_list.append(None)
    return op_list
    
def parse_nodes(dataset,node_list,seed = 0):
    cat_sig = []
    cat_txid = []
    data = dataset['data']
    
    
    for i,node in enumerate(node_list):
        if (not node  is  None) and  node < len(data):
            cat_sig.append(data[node])
            cat_txid.append(np.ones( (data[node].shape[0]) )*i)
    cat_sig = np.concatenate(cat_sig)
    cat_txid = np.concatenate(cat_txid)
    np.random.seed(seed)
    cat_sig,cat_txid = shuffle(cat_sig,cat_txid)
    cat_sig = norm(cat_sig)
    return (cat_sig,cat_txid)

def to_categorical(y, num_classes=None, dtype='float32'):
    y = np.array(y, dtype='int')
    input_shape = y.shape
    if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
        input_shape = tuple(input_shape[:-1])
    y = y.ravel()
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes), dtype=dtype)
    categorical[np.arange(n), y] = 1
    output_shape = input_shape + (num_classes,)
    categorical = np.reshape(categorical, output_shape)
    return categorical

def prepare_txid_and_weights(st,n):
    sig,txid = st
    txid_oh = to_categorical(txid,n)
    stat= np.sum(txid_oh,axis=0)
    cls_weights = np.max(stat,axis=0)/stat 
    cls_weights = cls_weights.tolist()
    augset = [sig,txid,txid_oh,cls_weights]
    return augset

def prepare_dataset(dataset,tx_name_list,val_frac=0.1, test_frac=0.1):
    tx_list = get_node_indices(tx_name_list,dataset['node_list'])
    all_set = parse_nodes(dataset,tx_list,seed = 0)
    train_set,val_set,test_set = split_set3(all_set,val_frac, test_frac)
    train_augset = prepare_txid_and_weights(train_set,len(tx_list))
    val_augset = prepare_txid_and_weights(val_set,len(tx_list))
    test_augset = prepare_txid_and_weights(test_set,len(tx_list))
    return train_augset,val_augset,test_augset


def create_dataset_impl(tx_list,rx_list,capture_date_list,max_sig=None,equalized_list=[0],full_dataset_path = 'data/',op_dataset_file = None):
    dataset = {}
    dataset['tx_list'] = tx_list
    dataset['rx_list'] = rx_list
    dataset['capture_date_list']=capture_date_list
    dataset['equalized_list'] = equalized_list
    dataset['max_sig'] = max_sig
    
    n_tx = len(tx_list)
    n_rx = len(rx_list)
    n_day = len(capture_date_list)
    n_eq = len(equalized_list)
    
    prefix_lut = [None,'eq']
    
    prefix_list = [prefix_lut[tt] for tt in  equalized_list]
    
    dataset['data'] = [ [ [ [ [ ] for _ in range(n_eq)] for _ in range(n_day) ] for _ in range(n_rx) ]  for _ in range(n_tx)     ]
    
    
    missing_rx_dict = {}
    
    missing_files = False

    
    with open('IdSig_info.pkl','rb') as f:
        IdSig_info=pickle.load(f)
    
    slc = slice(None,max_sig)
    for day_i,capture_date in enumerate(capture_date_list):
        for rx_i,rx_train in enumerate(rx_list):
            for eq_i,prefix in enumerate(prefix_list):
                tdataset = load_from_full_dataset(full_dataset_path,capture_date,rx_train,prefix=prefix)
                if not tdataset is None:
                    for tx_i,tx in enumerate(tx_list):
                        if tx in tdataset['node_list']:
                            tx_indx = tdataset['node_list'].index(tx)
                            dataset['data'][tx_i][rx_i][day_i][eq_i]= tdataset['data'][tx_indx][slc]  
                        else:
                            dataset['data'][tx_i][rx_i][day_i][eq_i]=np.zeros((0,256,2))
                else:
                    missing_rx_name =rx_list[rx_i]  
                    eq_val = equalized_list[eq_i]
                    IdSig_info_sub  = IdSig_info[eq_val][capture_date]
                    if missing_rx_name  in IdSig_info_sub.keys():
                            missing_files = True
                            if not eq_val in  missing_rx_dict.keys():
                                missing_rx_dict[eq_val]={}
                            if not capture_date in  missing_rx_dict[eq_val].keys():
                                missing_rx_dict[eq_val][capture_date]=[]
                            missing_rx_info  = IdSig_info_sub[missing_rx_name]
                            missing_rx_dict[eq_val][capture_date].append(   (missing_rx_info['name'], missing_rx_info['link'],missing_rx_info['size']) )

    
    if missing_files:
        ii=1
        total_file_sizes = 0
        print('You have missing files that you need to download.')
        
        for eq_k  in missing_rx_dict.keys():  
            if len(missing_rx_dict[eq_val])>0:
                print('')
                if eq_k==0:
                    print('You need to download the following files for the non equalized dataset')
                else:
                    print('You need to download the following files for the equalized dataset')
                
                print('')
                
                for date_k  in missing_rx_dict[eq_k].keys():  
                    for missing_rx in missing_rx_dict[eq_val][date_k]:
                        print('{}) Name: {} , Size: {} MB'.format(ii,missing_rx[0],missing_rx[2]/1e6))
                        total_file_sizes=total_file_sizes+missing_rx[2]
                        ii=ii+1
                print('Links:')
                for date_k  in missing_rx_dict[eq_k].keys():  
                    for missing_rx in missing_rx_dict[eq_val][date_k]:
                        print('https://drive.google.com/u/0/uc?export=download&id={}'.format(missing_rx[1]))               
        print('')
        print('You need to dowlnoad {} GB'.format(total_file_sizes/1e9))
        print('Note the following:')
        print('1) The non-equalized and eqalized files need to be downloaded in different fodlers because they share the same exact names')
        print('2) The  non-equalized folders needs to be grouped by date and equalization using the same structure as the following google drive folder')
        print('https://drive.google.com/drive/folders/1r8cd4zZ7fwvN_iiyI_uDKbIFGZve49lw?usp=sharing')
        print('3) If you have already downloaded the files make sure that the full dataset path is configured correctly.')
        dataset = None
    else:
        if not op_dataset_file is None:
            with open(op_dataset_file,'wb') as f:
                pickle.dump(dataset,f)
                print('Dataset saved in {}'.format(op_dataset_file))

    return dataset


def merge_compact_dataset(compact_dataset,capture_date,tx_list,rx_list,max_sig=None,equalized=0):
    dataset = {}
    dataset['node_list'] = tx_list
    dataset['data'] = [ () for _ in range(len(tx_list))]
    
    if not type(capture_date) is list: 
        capture_date_list = [capture_date]
    else:
        capture_date_list = capture_date
    slc = slice(None,max_sig)
    for capture_date in capture_date_list:
        for rx_train in rx_list:
            for indx,tx in enumerate(tx_list):
                tx_i=compact_dataset['tx_list'].index(tx)
                rx_i=compact_dataset['rx_list'].index(rx_train)
                date_i=compact_dataset['capture_date_list'].index(capture_date)
                eq_i=compact_dataset['equalized_list'].index(equalized)
                dataset['data'][indx]  +=  (compact_dataset['data'][tx_i][rx_i][date_i][eq_i][slc],)
    for indx in range(len(tx_list)):
        if len(dataset['data'][indx])>0:
            dataset['data'][indx] =  np.concatenate(dataset['data'][indx])
        else:
            dataset['data'][indx] =np.zeros((0,256,2))
    return dataset

# %% [markdown]
# ## Model

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
import os.path

import scipy,scipy.spatial
import matplotlib
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
with zipfile.ZipFile("/content/drive/MyDrive/ManyRx.pkl.zip", 'r') as zip_ref:
    zip_ref.extractall("./")

# %%
def load_compact_pkl_dataset(dataset_path,dataset_name):
    with open(dataset_path+dataset_name+'.pkl','rb') as f:
        dataset = pickle.load(f)
    return dataset

compact_dataset = load_compact_pkl_dataset("./","ManyRx")

tx_list = compact_dataset['tx_list']
rx_list = compact_dataset['rx_list']

equalized = 0

capture_date_list = compact_dataset['capture_date_list']
capture_date = capture_date_list[0]
n_tx = len(tx_list)
n_rx = len(rx_list)
print(n_tx,n_rx)
# Out:
# 10 32

# %%
compact_dataset.keys()
# Out:
# dict_keys(['tx_list', 'rx_list', 'capture_date_list', 'equalized_list', 'max_sig', 'data'])

# %%
np.random.seed(0)
n_real = 5
rx_list_real = []
for i in range(n_real):
    np.random.shuffle(rx_list)
    rx_list_real.append(np.copy(rx_list).tolist())
print(rx_list_real)
# Out:
# [['19-20', '24-13', '19-2', '1-20', '20-20', '20-1', '7-7', '3-19', '23-6', '2-19', '24-5', '14-7', '23-1', '19-1', '8-7', '24-6', '24-16', '1-19', '8-8', '18-19', '13-7', '23-3', '8-14', '23-5', '19-19', '18-2', '7-14', '13-14', '1-1', '23-7', '20-19', '2-1'], ['1-1', '23-1', '24-6', '8-8', '1-19', '23-3', '23-5', '7-14', '19-19', '13-14', '23-6', '7-7', '19-1', '20-1', '20-20', '24-16', '8-14', '19-2', '14-7', '1-20', '13-7', '24-5', '18-2', '2-19', '24-13', '19-20', '3-19', '8-7', '20-19', '2-1', '23-7', '18-19'], ['24-5', '23-7', '18-19', '23-3', '24-6', '8-14', '2-1', '13-7', '19-19', '19-2', '18-2', '1-20', '20-1', '24-16', '3-19', '1-19', '24-13', '23-6', '19-1', '8-7', '20-19', '1-1', '14-7', '20-20', '7-7', '2-19', '23-5', '8-8', '19-20', '13-14', '7-14', '23-1'], ['1-20', '1-19', '20-19', '23-7', '2-1', '20-1', '19-19', '14-7', '23-1', '3-19', '8-8', '7-7', '13-7', '20-20', '24-16', '18-2', '8-7', '23-5', '7-14', '18-19', '24-6', '19-1', '13-14', '2-19', '19-20', '24-5', '23-3', '19-2', '8-14', '23-6', '24-13', '1-1'], ['18-19', '20-1', '13-14', '18-2', '14-7', '20-20', '13-7', '19-20', '2-19', '19-19', '19-1', '1-20', '24-5', '20-19', '8-7', '23-1', '7-7', '8-8', '2-1', '1-19', '3-19', '23-3', '23-6', '23-5', '24-6', '8-14', '24-16', '7-14', '1-1', '19-2', '24-13', '23-7']]

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K

# %%
# !pip install attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting attention
#   Downloading attention-5.0.0-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from attention) (1.22.4)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.10/dist-packages (from attention) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1->attention) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.1->attention) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.1->attention) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.1->attention) (3.2.2)
# Installing collected packages: attention
# Successfully installed attention-5.0.0

# %%
# https://github.com/philipperemy/keras-attention
from attention import Attention

# %%
def create_net():

    inputs = Input(shape=(256,2))
    #x = Reshape((256,2,1))(inputs)

    x = LSTM(64, return_sequences=True)(inputs)
    '''
    x = Conv2D(8,(3,2),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,1))(x)
    x = Conv2D(16,(3,2),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,1))(x)
    x = Conv2D(16,(3,2),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,2))(x)
    x = Conv2D(32,(3,1),activation='relu',padding = 'same')(x)
    x = MaxPool2D((2,1))(x)
    x = Conv2D(16,(3,1),activation='relu',padding = 'same')(x)
    '''
    #x = Attention(units=32)(x)
    x = LSTM(64, return_sequences=False)(x)
    #x = resnet(x,64,(3,2),'6')
    #x = MaxPool2D((2,2))(x)
    x = Flatten()(x)



    x = Dense(100, activation='relu', kernel_regularizer = keras.regularizers.l2(0.0001))(x)
    # x = Dropout(0.3)(x)
    x = Dense(80, activation='relu',kernel_regularizer = keras.regularizers.l2(0.0001))(x)
    x = Dropout(0.5)(x)
    x = Dense(n_tx, activation='softmax',kernel_regularizer = keras.regularizers.l2(0.0001))(x)
    ops = x

    classifier = Model(inputs,ops)
    classifier.compile(loss='categorical_crossentropy',metrics=['categorical_accuracy'],optimizer=keras.optimizers.Adam(0.0005))
    
    return classifier

classifier = create_net()
classifier.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 2)]          0
#
#  lstm_2 (LSTM)               (None, 256, 64)           17152
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 100)               6500
#
#  dense_4 (Dense)             (None, 80)                8080
#
#  dropout_1 (Dropout)         (None, 80)                0
#
#  dense_5 (Dense)             (None, 10)                810
#
# =================================================================
# Total params: 65,566
# Trainable params: 65,566
# Non-trainable params: 0
# _________________________________________________________________

# %%
def evaluate_test(classifier):
    pred = classifier.predict(sig_dfTest)
    acc = np.mean(np.argmax(pred,1)==txidNum_dfTest)

    test_indx = ()
    for indx in range(len(tx_list)):
        cls_indx = np.where(txidNum_dfTest == indx)
        test_indx = test_indx + (cls_indx[0][:n_test_samples],)
    test_indx = np.concatenate(test_indx) 
    acc_bal = np.mean(np.argmax(pred[test_indx,:],1)==txidNum_dfTest[test_indx])
    return acc,acc_bal

# %%
n_test_rx = 5

# %%
# !mkdir weights

# %%
tf.get_logger().setLevel('ERROR')
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
TRAIN = True
continue_training = True
nreal = 5

real_list = list(range(nreal))
nrx_list =  list(range( 0,len(rx_list_real[0])-n_test_rx+1,5))  # [0,len(rx_list_real[0])-1] #

patience = 5
n_epochs = 100

smTest_results = []
dfTest_results = []
dfTestBal_results = []

for real in real_list:
    rx_list = rx_list_real[real]
    rx_test_list = rx_list[-n_test_rx:]
    test_dataset = merge_compact_dataset(compact_dataset,capture_date,tx_list,rx_test_list)
    test_augset_dfRx,_,_ = prepare_dataset(test_dataset,tx_list,val_frac=0.0, test_frac=0.0)

    [sig_dfTest,txidNum_dfTest,txid_dfTest,cls_weights] = test_augset_dfRx
    
    cnt=np.histogram(txidNum_dfTest,bins=np.arange(len(tx_list)+1)-0.5)
    n_test_samples = int(np.min(cnt[0]))

    smTest_results_real = []
    dfTest_results_real = []
    dfTestBal_results_real = []
    for nrx in nrx_list:
        print("");print("")
        print("nrx: {} - real: {} ".format(nrx,real))
        fname_w = 'weights/d003_{:02d}_{:02d}.hd5'.format(nrx,real)
        rx_train_list= rx_list[:nrx+1]

        dataset = merge_compact_dataset(compact_dataset,capture_date,tx_list,rx_train_list)

        train_augset,val_augset,test_augset_smRx =  prepare_dataset(dataset,tx_list,
                                                            val_frac=0.1, test_frac=0.1)
        [sig_train,txidNum_train,txid_train,cls_weights] = train_augset
        [sig_valid,txidNum_valid,txid_valid,_] = val_augset
        [sig_smTest,txidNum_smTest,txid_smTest,cls_weights] = test_augset_smRx
        
        spl_weights = np.zeros((len(sig_train)))
        for index in range(len(txid_train)):
          spl_weights[index] = cls_weights[np.argmax(txid_train[index])]


        if continue_training:
            skip = os.path.isfile(fname_w)
        else:
            skip = False
        classifier = create_net()
        with tf.device('/device:GPU:0'):
          if TRAIN and not skip:
              filepath = 't_weights_0'
              c=[ keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True),
                keras.callbacks.EarlyStopping(monitor='val_loss',  patience=patience)]
              #history = classifier.fit(sig_train,txid_train,class_weight=cls_weights,validation_data=(sig_valid , txid_valid),callbacks=c, epochs=n_epochs)
              history = classifier.fit(sig_train,txid_train,sample_weight=spl_weights,
                                      validation_data=(sig_valid , txid_valid),callbacks=c, epochs=n_epochs, verbose=2)
              classifier.load_weights(filepath)
              classifier.save_weights(fname_w,save_format="h5")
          else:
              classifier.load_weights(fname_w)

        smTest_r = classifier.evaluate(sig_smTest,txid_smTest,verbose=0)[1]
    #     dfTest_r = classifier.evaluate(sig_dfTest,txid_dfTest)[1]
        dfTest_r,dfTestBal_r = evaluate_test(classifier)

        print(smTest_r,dfTest_r)
        smTest_results_real.append(smTest_r)
        dfTest_results_real.append(dfTest_r)
        dfTestBal_results_real.append(dfTestBal_r)
        K.clear_session()
    smTest_results.append(smTest_results_real)
    dfTest_results.append(dfTest_results_real)
    dfTestBal_results.append(dfTestBal_results_real)
# Out:
# <ipython-input-1-e7494fe5acc6>:119: RuntimeWarning: invalid value encountered in true_divide
#   cls_weights = np.max(stat,axis=0)/stat
# nrx: 0 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.31551, saving model to t_weights_0
# 50/50 - 21s - loss: 2.9768 - categorical_accuracy: 0.1112 - val_loss: 2.3155 - val_categorical_accuracy: 0.1350 - 21s/epoch - 411ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.31551 to 2.26132, saving model to t_weights_0
# 50/50 - 8s - loss: 2.9305 - categorical_accuracy: 0.1281 - val_loss: 2.2613 - val_categorical_accuracy: 0.1500 - 8s/epoch - 169ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 2.26132 to 1.90019, saving model to t_weights_0
# 50/50 - 11s - loss: 2.5966 - categorical_accuracy: 0.2119 - val_loss: 1.9002 - val_categorical_accuracy: 0.2000 - 11s/epoch - 216ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.90019 to 1.59033, saving model to t_weights_0
# 50/50 - 9s - loss: 2.2481 - categorical_accuracy: 0.2944 - val_loss: 1.5903 - val_categorical_accuracy: 0.4250 - 9s/epoch - 185ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.59033 to 1.41584, saving model to t_weights_0
# 50/50 - 9s - loss: 2.0264 - categorical_accuracy: 0.3638 - val_loss: 1.4158 - val_categorical_accuracy: 0.4900 - 9s/epoch - 179ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 1.41584
# 50/50 - 1s - loss: 1.9745 - categorical_accuracy: 0.3969 - val_loss: 2.0116 - val_categorical_accuracy: 0.2800 - 1s/epoch - 24ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.41584 to 1.32272, saving model to t_weights_0
# 50/50 - 9s - loss: 1.9356 - categorical_accuracy: 0.3981 - val_loss: 1.3227 - val_categorical_accuracy: 0.5250 - 9s/epoch - 179ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.32272 to 1.21112, saving model to t_weights_0
# 50/50 - 9s - loss: 1.6833 - categorical_accuracy: 0.4806 - val_loss: 1.2111 - val_categorical_accuracy: 0.5800 - 9s/epoch - 189ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.21112
# 50/50 - 1s - loss: 1.9330 - categorical_accuracy: 0.4369 - val_loss: 1.9189 - val_categorical_accuracy: 0.3350 - 977ms/epoch - 20ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 1.21112
# 50/50 - 1s - loss: 2.7506 - categorical_accuracy: 0.2456 - val_loss: 2.0274 - val_categorical_accuracy: 0.2600 - 805ms/epoch - 16ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.21112
# 50/50 - 1s - loss: 2.5267 - categorical_accuracy: 0.2969 - val_loss: 1.8655 - val_categorical_accuracy: 0.3150 - 808ms/epoch - 16ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.21112
# 50/50 - 1s - loss: 2.3174 - categorical_accuracy: 0.3537 - val_loss: 1.9546 - val_categorical_accuracy: 0.2350 - 799ms/epoch - 16ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 1.21112
# 50/50 - 1s - loss: 2.3748 - categorical_accuracy: 0.2775 - val_loss: 1.8879 - val_categorical_accuracy: 0.2450 - 802ms/epoch - 16ms/step
# 313/313 [==============================] - 3s 8ms/step
# 0.625 0.0634
#
#
# nrx: 5 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.12919, saving model to t_weights_0
# 295/295 - 18s - loss: 2.7092 - categorical_accuracy: 0.1363 - val_loss: 2.1292 - val_categorical_accuracy: 0.2500 - 18s/epoch - 61ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.12919 to 1.71481, saving model to t_weights_0
# 295/295 - 14s - loss: 2.4340 - categorical_accuracy: 0.2593 - val_loss: 1.7148 - val_categorical_accuracy: 0.3814 - 14s/epoch - 47ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.71481 to 1.24682, saving model to t_weights_0
# 295/295 - 13s - loss: 1.8805 - categorical_accuracy: 0.4524 - val_loss: 1.2468 - val_categorical_accuracy: 0.5644 - 13s/epoch - 43ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.24682 to 0.96998, saving model to t_weights_0
# 295/295 - 13s - loss: 1.4770 - categorical_accuracy: 0.5876 - val_loss: 0.9700 - val_categorical_accuracy: 0.6788 - 13s/epoch - 45ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.96998 to 0.83440, saving model to t_weights_0
# 295/295 - 13s - loss: 1.2396 - categorical_accuracy: 0.6661 - val_loss: 0.8344 - val_categorical_accuracy: 0.7508 - 13s/epoch - 45ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.83440
# 295/295 - 6s - loss: 1.1031 - categorical_accuracy: 0.7185 - val_loss: 1.2385 - val_categorical_accuracy: 0.5831 - 6s/epoch - 19ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.83440 to 0.73838, saving model to t_weights_0
# 295/295 - 13s - loss: 1.1320 - categorical_accuracy: 0.7077 - val_loss: 0.7384 - val_categorical_accuracy: 0.7653 - 13s/epoch - 45ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.73838 to 0.66173, saving model to t_weights_0
# 295/295 - 13s - loss: 0.9536 - categorical_accuracy: 0.7630 - val_loss: 0.6617 - val_categorical_accuracy: 0.7881 - 13s/epoch - 45ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.66173 to 0.57860, saving model to t_weights_0
# 295/295 - 13s - loss: 0.8684 - categorical_accuracy: 0.7890 - val_loss: 0.5786 - val_categorical_accuracy: 0.8246 - 13s/epoch - 43ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.57860 to 0.56689, saving model to t_weights_0
# 295/295 - 13s - loss: 0.8634 - categorical_accuracy: 0.7904 - val_loss: 0.5669 - val_categorical_accuracy: 0.8237 - 13s/epoch - 46ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.56689 to 0.54835, saving model to t_weights_0
# 295/295 - 13s - loss: 0.7412 - categorical_accuracy: 0.8244 - val_loss: 0.5484 - val_categorical_accuracy: 0.8364 - 13s/epoch - 44ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.54835
# 295/295 - 5s - loss: 0.7871 - categorical_accuracy: 0.8141 - val_loss: 0.5652 - val_categorical_accuracy: 0.8297 - 5s/epoch - 17ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.54835 to 0.46578, saving model to t_weights_0
# 295/295 - 13s - loss: 0.6953 - categorical_accuracy: 0.8394 - val_loss: 0.4658 - val_categorical_accuracy: 0.8754 - 13s/epoch - 44ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.46578 to 0.43487, saving model to t_weights_0
# 295/295 - 13s - loss: 0.7557 - categorical_accuracy: 0.8272 - val_loss: 0.4349 - val_categorical_accuracy: 0.8856 - 13s/epoch - 45ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.43487 to 0.40058, saving model to t_weights_0
# 295/295 - 13s - loss: 0.6110 - categorical_accuracy: 0.8614 - val_loss: 0.4006 - val_categorical_accuracy: 0.8898 - 13s/epoch - 43ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.40058
# 295/295 - 5s - loss: 0.8867 - categorical_accuracy: 0.7931 - val_loss: 0.5118 - val_categorical_accuracy: 0.8398 - 5s/epoch - 16ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.40058 to 0.39531, saving model to t_weights_0
# 295/295 - 14s - loss: 0.6313 - categorical_accuracy: 0.8638 - val_loss: 0.3953 - val_categorical_accuracy: 0.8975 - 14s/epoch - 49ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.39531
# 295/295 - 5s - loss: 0.5471 - categorical_accuracy: 0.8819 - val_loss: 0.4323 - val_categorical_accuracy: 0.8788 - 5s/epoch - 16ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.39531
# 295/295 - 6s - loss: 0.6951 - categorical_accuracy: 0.8416 - val_loss: 0.5489 - val_categorical_accuracy: 0.8466 - 6s/epoch - 19ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.39531
# 295/295 - 5s - loss: 0.6003 - categorical_accuracy: 0.8657 - val_loss: 0.4190 - val_categorical_accuracy: 0.8847 - 5s/epoch - 15ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.39531 to 0.35315, saving model to t_weights_0
# 295/295 - 13s - loss: 0.5473 - categorical_accuracy: 0.8778 - val_loss: 0.3532 - val_categorical_accuracy: 0.9025 - 13s/epoch - 44ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.35315
# 295/295 - 5s - loss: 0.5282 - categorical_accuracy: 0.8832 - val_loss: 0.4144 - val_categorical_accuracy: 0.8847 - 5s/epoch - 18ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.35315 to 0.34560, saving model to t_weights_0
# 295/295 - 13s - loss: 0.5178 - categorical_accuracy: 0.8820 - val_loss: 0.3456 - val_categorical_accuracy: 0.9068 - 13s/epoch - 44ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.34560
# 295/295 - 5s - loss: 0.5374 - categorical_accuracy: 0.8780 - val_loss: 0.5131 - val_categorical_accuracy: 0.8593 - 5s/epoch - 18ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.34560
# 295/295 - 5s - loss: 1.1252 - categorical_accuracy: 0.7257 - val_loss: 0.4258 - val_categorical_accuracy: 0.8780 - 5s/epoch - 15ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.34560
# 295/295 - 5s - loss: 0.5054 - categorical_accuracy: 0.8856 - val_loss: 0.4537 - val_categorical_accuracy: 0.8695 - 5s/epoch - 19ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.34560 to 0.33174, saving model to t_weights_0
# 295/295 - 13s - loss: 0.5223 - categorical_accuracy: 0.8793 - val_loss: 0.3317 - val_categorical_accuracy: 0.9068 - 13s/epoch - 44ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.33174 to 0.32699, saving model to t_weights_0
# 295/295 - 13s - loss: 0.4410 - categorical_accuracy: 0.8997 - val_loss: 0.3270 - val_categorical_accuracy: 0.9119 - 13s/epoch - 45ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.32699 to 0.31973, saving model to t_weights_0
# 295/295 - 12s - loss: 0.4534 - categorical_accuracy: 0.8934 - val_loss: 0.3197 - val_categorical_accuracy: 0.9119 - 12s/epoch - 42ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.31973
# 295/295 - 5s - loss: 0.4185 - categorical_accuracy: 0.9047 - val_loss: 0.3323 - val_categorical_accuracy: 0.9110 - 5s/epoch - 18ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.31973
# 295/295 - 5s - loss: 0.4903 - categorical_accuracy: 0.8865 - val_loss: 0.3847 - val_categorical_accuracy: 0.8907 - 5s/epoch - 15ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.31973 to 0.31661, saving model to t_weights_0
# 295/295 - 13s - loss: 0.4551 - categorical_accuracy: 0.8932 - val_loss: 0.3166 - val_categorical_accuracy: 0.9136 - 13s/epoch - 45ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.31661
# 295/295 - 6s - loss: 0.3849 - categorical_accuracy: 0.9101 - val_loss: 0.3228 - val_categorical_accuracy: 0.9110 - 6s/epoch - 19ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.31661
# 295/295 - 5s - loss: 0.4392 - categorical_accuracy: 0.8983 - val_loss: 0.3681 - val_categorical_accuracy: 0.8975 - 5s/epoch - 15ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.31661
# 295/295 - 4s - loss: 0.4292 - categorical_accuracy: 0.8999 - val_loss: 0.3351 - val_categorical_accuracy: 0.9144 - 4s/epoch - 15ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.31661
# 295/295 - 6s - loss: 0.4125 - categorical_accuracy: 0.9038 - val_loss: 0.3302 - val_categorical_accuracy: 0.9127 - 6s/epoch - 19ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.31661
# 295/295 - 4s - loss: 0.3960 - categorical_accuracy: 0.9089 - val_loss: 0.3340 - val_categorical_accuracy: 0.9119 - 4s/epoch - 15ms/step
# 313/313 [==============================] - 3s 7ms/step
# 0.8932203650474548 0.6488
#
#
# nrx: 10 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.51649, saving model to t_weights_0
# 545/545 - 22s - loss: 2.2980 - categorical_accuracy: 0.2368 - val_loss: 1.5165 - val_categorical_accuracy: 0.4450 - 22s/epoch - 40ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.51649 to 1.02712, saving model to t_weights_0
# 545/545 - 17s - loss: 1.5149 - categorical_accuracy: 0.5280 - val_loss: 1.0271 - val_categorical_accuracy: 0.6725 - 17s/epoch - 31ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 1.02712
# 545/545 - 9s - loss: 1.2216 - categorical_accuracy: 0.6431 - val_loss: 1.1611 - val_categorical_accuracy: 0.5697 - 9s/epoch - 17ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.02712 to 0.81348, saving model to t_weights_0
# 545/545 - 18s - loss: 1.0605 - categorical_accuracy: 0.7065 - val_loss: 0.8135 - val_categorical_accuracy: 0.7445 - 18s/epoch - 33ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.81348 to 0.70111, saving model to t_weights_0
# 545/545 - 18s - loss: 0.9203 - categorical_accuracy: 0.7570 - val_loss: 0.7011 - val_categorical_accuracy: 0.7894 - 18s/epoch - 33ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.70111 to 0.68000, saving model to t_weights_0
# 545/545 - 17s - loss: 0.8501 - categorical_accuracy: 0.7842 - val_loss: 0.6800 - val_categorical_accuracy: 0.8138 - 17s/epoch - 31ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.68000 to 0.64099, saving model to t_weights_0
# 545/545 - 17s - loss: 0.8198 - categorical_accuracy: 0.7894 - val_loss: 0.6410 - val_categorical_accuracy: 0.8243 - 17s/epoch - 31ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.64099 to 0.58425, saving model to t_weights_0
# 545/545 - 17s - loss: 0.7558 - categorical_accuracy: 0.8140 - val_loss: 0.5842 - val_categorical_accuracy: 0.8431 - 17s/epoch - 31ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.58425 to 0.57862, saving model to t_weights_0
# 545/545 - 18s - loss: 0.7420 - categorical_accuracy: 0.8140 - val_loss: 0.5786 - val_categorical_accuracy: 0.8367 - 18s/epoch - 33ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.57862 to 0.55120, saving model to t_weights_0
# 545/545 - 17s - loss: 0.6769 - categorical_accuracy: 0.8348 - val_loss: 0.5512 - val_categorical_accuracy: 0.8528 - 17s/epoch - 32ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.55120 to 0.49842, saving model to t_weights_0
# 545/545 - 17s - loss: 0.6289 - categorical_accuracy: 0.8505 - val_loss: 0.4984 - val_categorical_accuracy: 0.8624 - 17s/epoch - 31ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.49842
# 545/545 - 9s - loss: 0.6575 - categorical_accuracy: 0.8407 - val_loss: 0.6271 - val_categorical_accuracy: 0.8216 - 9s/epoch - 17ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.49842 to 0.48320, saving model to t_weights_0
# 545/545 - 17s - loss: 0.5932 - categorical_accuracy: 0.8593 - val_loss: 0.4832 - val_categorical_accuracy: 0.8693 - 17s/epoch - 31ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.48320
# 545/545 - 10s - loss: 0.5812 - categorical_accuracy: 0.8620 - val_loss: 0.5326 - val_categorical_accuracy: 0.8509 - 10s/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.48320 to 0.45817, saving model to t_weights_0
# 545/545 - 16s - loss: 0.5591 - categorical_accuracy: 0.8686 - val_loss: 0.4582 - val_categorical_accuracy: 0.8766 - 16s/epoch - 30ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.45817
# 545/545 - 9s - loss: 0.5352 - categorical_accuracy: 0.8743 - val_loss: 0.5004 - val_categorical_accuracy: 0.8587 - 9s/epoch - 17ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.45817 to 0.43479, saving model to t_weights_0
# 545/545 - 17s - loss: 0.5118 - categorical_accuracy: 0.8826 - val_loss: 0.4348 - val_categorical_accuracy: 0.8858 - 17s/epoch - 32ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.43479
# 545/545 - 10s - loss: 0.4936 - categorical_accuracy: 0.8842 - val_loss: 0.5271 - val_categorical_accuracy: 0.8500 - 10s/epoch - 18ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.43479 to 0.42217, saving model to t_weights_0
# 545/545 - 17s - loss: 0.4864 - categorical_accuracy: 0.8853 - val_loss: 0.4222 - val_categorical_accuracy: 0.8784 - 17s/epoch - 31ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.42217 to 0.38054, saving model to t_weights_0
# 545/545 - 17s - loss: 0.4537 - categorical_accuracy: 0.8945 - val_loss: 0.3805 - val_categorical_accuracy: 0.9028 - 17s/epoch - 32ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.38054
# 545/545 - 10s - loss: 0.4740 - categorical_accuracy: 0.8896 - val_loss: 0.5549 - val_categorical_accuracy: 0.8509 - 10s/epoch - 19ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.38054
# 545/545 - 9s - loss: 0.4490 - categorical_accuracy: 0.8947 - val_loss: 0.4031 - val_categorical_accuracy: 0.8927 - 9s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.38054
# 545/545 - 8s - loss: 0.4413 - categorical_accuracy: 0.8966 - val_loss: 0.4172 - val_categorical_accuracy: 0.8867 - 8s/epoch - 16ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.38054
# 545/545 - 9s - loss: 0.5205 - categorical_accuracy: 0.8759 - val_loss: 0.4191 - val_categorical_accuracy: 0.8927 - 9s/epoch - 17ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.38054 to 0.35937, saving model to t_weights_0
# 545/545 - 17s - loss: 0.4285 - categorical_accuracy: 0.8998 - val_loss: 0.3594 - val_categorical_accuracy: 0.9055 - 17s/epoch - 31ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.35937
# 545/545 - 9s - loss: 0.3760 - categorical_accuracy: 0.9132 - val_loss: 0.3646 - val_categorical_accuracy: 0.8968 - 9s/epoch - 17ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.35937 to 0.35483, saving model to t_weights_0
# 545/545 - 17s - loss: 0.3908 - categorical_accuracy: 0.9075 - val_loss: 0.3548 - val_categorical_accuracy: 0.9055 - 17s/epoch - 31ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.35483 to 0.33787, saving model to t_weights_0
# 545/545 - 18s - loss: 0.3716 - categorical_accuracy: 0.9153 - val_loss: 0.3379 - val_categorical_accuracy: 0.9138 - 18s/epoch - 33ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.33787 to 0.33233, saving model to t_weights_0
# 545/545 - 18s - loss: 0.3959 - categorical_accuracy: 0.9077 - val_loss: 0.3323 - val_categorical_accuracy: 0.9138 - 18s/epoch - 32ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.33233 to 0.32151, saving model to t_weights_0
# 545/545 - 17s - loss: 0.3590 - categorical_accuracy: 0.9171 - val_loss: 0.3215 - val_categorical_accuracy: 0.9170 - 17s/epoch - 32ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.32151
# 545/545 - 10s - loss: 0.3762 - categorical_accuracy: 0.9109 - val_loss: 0.4679 - val_categorical_accuracy: 0.8743 - 10s/epoch - 18ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.32151 to 0.31593, saving model to t_weights_0
# 545/545 - 18s - loss: 0.3219 - categorical_accuracy: 0.9236 - val_loss: 0.3159 - val_categorical_accuracy: 0.9183 - 18s/epoch - 33ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.31593
# 545/545 - 10s - loss: 0.3260 - categorical_accuracy: 0.9233 - val_loss: 0.3238 - val_categorical_accuracy: 0.9151 - 10s/epoch - 18ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.31593
# 545/545 - 10s - loss: 0.3737 - categorical_accuracy: 0.9107 - val_loss: 0.3224 - val_categorical_accuracy: 0.9188 - 10s/epoch - 18ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.31593
# 545/545 - 8s - loss: 0.3053 - categorical_accuracy: 0.9277 - val_loss: 0.4143 - val_categorical_accuracy: 0.8894 - 8s/epoch - 16ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.31593
# 545/545 - 10s - loss: 0.3446 - categorical_accuracy: 0.9173 - val_loss: 0.3274 - val_categorical_accuracy: 0.9151 - 10s/epoch - 18ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.31593 to 0.28509, saving model to t_weights_0
# 545/545 - 18s - loss: 0.2901 - categorical_accuracy: 0.9308 - val_loss: 0.2851 - val_categorical_accuracy: 0.9271 - 18s/epoch - 33ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.28509
# 545/545 - 10s - loss: 0.3271 - categorical_accuracy: 0.9234 - val_loss: 0.3598 - val_categorical_accuracy: 0.9073 - 10s/epoch - 18ms/step
# Epoch 39/100
#
# Epoch 39: val_loss improved from 0.28509 to 0.28063, saving model to t_weights_0
# 545/545 - 18s - loss: 0.3043 - categorical_accuracy: 0.9286 - val_loss: 0.2806 - val_categorical_accuracy: 0.9298 - 18s/epoch - 32ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.28063
# 545/545 - 10s - loss: 0.2819 - categorical_accuracy: 0.9343 - val_loss: 0.3237 - val_categorical_accuracy: 0.9138 - 10s/epoch - 18ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.28063
# 545/545 - 11s - loss: 0.3063 - categorical_accuracy: 0.9292 - val_loss: 0.2992 - val_categorical_accuracy: 0.9234 - 11s/epoch - 20ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.28063
# 545/545 - 10s - loss: 0.2781 - categorical_accuracy: 0.9350 - val_loss: 0.3944 - val_categorical_accuracy: 0.8954 - 10s/epoch - 18ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.28063
# 545/545 - 8s - loss: 0.2939 - categorical_accuracy: 0.9326 - val_loss: 0.2845 - val_categorical_accuracy: 0.9289 - 8s/epoch - 16ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.28063
# 545/545 - 10s - loss: 0.2617 - categorical_accuracy: 0.9406 - val_loss: 0.3043 - val_categorical_accuracy: 0.9261 - 10s/epoch - 18ms/step
# 313/313 [==============================] - 3s 7ms/step
# 0.9357798099517822 0.8093
#
#
# nrx: 15 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.16582, saving model to t_weights_0
# 785/785 - 28s - loss: 2.0747 - categorical_accuracy: 0.3089 - val_loss: 1.1658 - val_categorical_accuracy: 0.6096 - 28s/epoch - 35ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.16582 to 0.95651, saving model to t_weights_0
# 785/785 - 23s - loss: 1.2869 - categorical_accuracy: 0.6166 - val_loss: 0.9565 - val_categorical_accuracy: 0.6742 - 23s/epoch - 29ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.95651
# 785/785 - 14s - loss: 1.0120 - categorical_accuracy: 0.7223 - val_loss: 1.1687 - val_categorical_accuracy: 0.6172 - 14s/epoch - 18ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.95651 to 0.60534, saving model to t_weights_0
# 785/785 - 24s - loss: 0.8721 - categorical_accuracy: 0.7722 - val_loss: 0.6053 - val_categorical_accuracy: 0.8236 - 24s/epoch - 30ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.60534 to 0.58800, saving model to t_weights_0
# 785/785 - 23s - loss: 0.7784 - categorical_accuracy: 0.8006 - val_loss: 0.5880 - val_categorical_accuracy: 0.8303 - 23s/epoch - 29ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.58800 to 0.55183, saving model to t_weights_0
# 785/785 - 23s - loss: 0.6891 - categorical_accuracy: 0.8297 - val_loss: 0.5518 - val_categorical_accuracy: 0.8379 - 23s/epoch - 30ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.55183 to 0.48821, saving model to t_weights_0
# 785/785 - 23s - loss: 0.6695 - categorical_accuracy: 0.8346 - val_loss: 0.4882 - val_categorical_accuracy: 0.8659 - 23s/epoch - 30ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.48821 to 0.46404, saving model to t_weights_0
# 785/785 - 23s - loss: 0.6400 - categorical_accuracy: 0.8437 - val_loss: 0.4640 - val_categorical_accuracy: 0.8761 - 23s/epoch - 29ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.46404 to 0.45462, saving model to t_weights_0
# 785/785 - 25s - loss: 0.5863 - categorical_accuracy: 0.8583 - val_loss: 0.4546 - val_categorical_accuracy: 0.8697 - 25s/epoch - 31ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.45462 to 0.43898, saving model to t_weights_0
# 785/785 - 24s - loss: 0.5815 - categorical_accuracy: 0.8598 - val_loss: 0.4390 - val_categorical_accuracy: 0.8783 - 24s/epoch - 31ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.43898 to 0.39506, saving model to t_weights_0
# 785/785 - 24s - loss: 0.5455 - categorical_accuracy: 0.8711 - val_loss: 0.3951 - val_categorical_accuracy: 0.8955 - 24s/epoch - 30ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.39506 to 0.37044, saving model to t_weights_0
# 785/785 - 24s - loss: 0.5349 - categorical_accuracy: 0.8715 - val_loss: 0.3704 - val_categorical_accuracy: 0.8981 - 24s/epoch - 31ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.37044
# 785/785 - 15s - loss: 0.5431 - categorical_accuracy: 0.8705 - val_loss: 0.4060 - val_categorical_accuracy: 0.8847 - 15s/epoch - 19ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.37044
# 785/785 - 15s - loss: 0.4728 - categorical_accuracy: 0.8877 - val_loss: 0.3803 - val_categorical_accuracy: 0.8939 - 15s/epoch - 19ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.37044 to 0.36914, saving model to t_weights_0
# 785/785 - 23s - loss: 0.4685 - categorical_accuracy: 0.8890 - val_loss: 0.3691 - val_categorical_accuracy: 0.8946 - 23s/epoch - 30ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.36914
# 785/785 - 15s - loss: 0.4614 - categorical_accuracy: 0.8908 - val_loss: 0.4443 - val_categorical_accuracy: 0.8739 - 15s/epoch - 19ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.36914
# 785/785 - 15s - loss: 0.4400 - categorical_accuracy: 0.8950 - val_loss: 0.4086 - val_categorical_accuracy: 0.8885 - 15s/epoch - 19ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.36914 to 0.33118, saving model to t_weights_0
# 785/785 - 24s - loss: 0.4413 - categorical_accuracy: 0.8961 - val_loss: 0.3312 - val_categorical_accuracy: 0.9092 - 24s/epoch - 31ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.33118
# 785/785 - 15s - loss: 0.4555 - categorical_accuracy: 0.8927 - val_loss: 0.6518 - val_categorical_accuracy: 0.8127 - 15s/epoch - 19ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.33118 to 0.33114, saving model to t_weights_0
# 785/785 - 24s - loss: 0.5256 - categorical_accuracy: 0.8717 - val_loss: 0.3311 - val_categorical_accuracy: 0.9134 - 24s/epoch - 31ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.33114 to 0.32858, saving model to t_weights_0
# 785/785 - 24s - loss: 0.4124 - categorical_accuracy: 0.9024 - val_loss: 0.3286 - val_categorical_accuracy: 0.9076 - 24s/epoch - 31ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.32858
# 785/785 - 15s - loss: 0.3881 - categorical_accuracy: 0.9066 - val_loss: 0.3518 - val_categorical_accuracy: 0.9076 - 15s/epoch - 19ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.32858 to 0.30053, saving model to t_weights_0
# 785/785 - 22s - loss: 0.3895 - categorical_accuracy: 0.9074 - val_loss: 0.3005 - val_categorical_accuracy: 0.9175 - 22s/epoch - 28ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.30053
# 785/785 - 14s - loss: 0.3954 - categorical_accuracy: 0.9059 - val_loss: 0.3677 - val_categorical_accuracy: 0.8949 - 14s/epoch - 18ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.30053
# 785/785 - 14s - loss: 0.4295 - categorical_accuracy: 0.8979 - val_loss: 0.3380 - val_categorical_accuracy: 0.9064 - 14s/epoch - 17ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.30053
# 785/785 - 14s - loss: 0.3847 - categorical_accuracy: 0.9073 - val_loss: 0.3258 - val_categorical_accuracy: 0.9096 - 14s/epoch - 18ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.30053
# 785/785 - 13s - loss: 0.3640 - categorical_accuracy: 0.9129 - val_loss: 0.3089 - val_categorical_accuracy: 0.9162 - 13s/epoch - 17ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.30053 to 0.26606, saving model to t_weights_0
# 785/785 - 22s - loss: 0.3595 - categorical_accuracy: 0.9132 - val_loss: 0.2661 - val_categorical_accuracy: 0.9274 - 22s/epoch - 27ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.26606
# 785/785 - 14s - loss: 0.3562 - categorical_accuracy: 0.9149 - val_loss: 0.3414 - val_categorical_accuracy: 0.9064 - 14s/epoch - 18ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.26606
# 785/785 - 14s - loss: 0.3449 - categorical_accuracy: 0.9152 - val_loss: 0.3352 - val_categorical_accuracy: 0.9041 - 14s/epoch - 17ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.26606
# 785/785 - 13s - loss: 0.3472 - categorical_accuracy: 0.9174 - val_loss: 0.9131 - val_categorical_accuracy: 0.7815 - 13s/epoch - 17ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.26606
# 785/785 - 13s - loss: 0.3418 - categorical_accuracy: 0.9185 - val_loss: 0.3169 - val_categorical_accuracy: 0.9150 - 13s/epoch - 17ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.26606
# 785/785 - 13s - loss: 0.3580 - categorical_accuracy: 0.9148 - val_loss: 0.2780 - val_categorical_accuracy: 0.9217 - 13s/epoch - 16ms/step
# 313/313 [==============================] - 3s 8ms/step
# 0.925159215927124 0.8248
#
#
# nrx: 20 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.11033, saving model to t_weights_0
# 1030/1030 - 32s - loss: 2.0242 - categorical_accuracy: 0.3247 - val_loss: 1.1103 - val_categorical_accuracy: 0.6367 - 32s/epoch - 31ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.11033 to 0.76115, saving model to t_weights_0
# 1030/1030 - 27s - loss: 1.1825 - categorical_accuracy: 0.6664 - val_loss: 0.7612 - val_categorical_accuracy: 0.7900 - 27s/epoch - 27ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.76115 to 0.61210, saving model to t_weights_0
# 1030/1030 - 28s - loss: 0.9177 - categorical_accuracy: 0.7619 - val_loss: 0.6121 - val_categorical_accuracy: 0.8337 - 28s/epoch - 27ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.61210 to 0.56544, saving model to t_weights_0
# 1030/1030 - 29s - loss: 0.7846 - categorical_accuracy: 0.8025 - val_loss: 0.5654 - val_categorical_accuracy: 0.8442 - 29s/epoch - 28ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.56544 to 0.54716, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.7129 - categorical_accuracy: 0.8231 - val_loss: 0.5472 - val_categorical_accuracy: 0.8425 - 26s/epoch - 25ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.54716 to 0.50245, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.6741 - categorical_accuracy: 0.8344 - val_loss: 0.5024 - val_categorical_accuracy: 0.8566 - 26s/epoch - 26ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.50245
# 1030/1030 - 19s - loss: 0.6241 - categorical_accuracy: 0.8451 - val_loss: 0.5216 - val_categorical_accuracy: 0.8500 - 19s/epoch - 18ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.50245 to 0.43717, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.5851 - categorical_accuracy: 0.8581 - val_loss: 0.4372 - val_categorical_accuracy: 0.8811 - 26s/epoch - 26ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.43717 to 0.39583, saving model to t_weights_0
# 1030/1030 - 25s - loss: 0.5532 - categorical_accuracy: 0.8653 - val_loss: 0.3958 - val_categorical_accuracy: 0.8922 - 25s/epoch - 24ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.39583
# 1030/1030 - 19s - loss: 0.5277 - categorical_accuracy: 0.8703 - val_loss: 0.5436 - val_categorical_accuracy: 0.8381 - 19s/epoch - 19ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.39583 to 0.37797, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.5097 - categorical_accuracy: 0.8762 - val_loss: 0.3780 - val_categorical_accuracy: 0.8971 - 27s/epoch - 26ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.37797
# 1030/1030 - 18s - loss: 0.5018 - categorical_accuracy: 0.8795 - val_loss: 0.4160 - val_categorical_accuracy: 0.8854 - 18s/epoch - 17ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.37797
# 1030/1030 - 19s - loss: 0.4737 - categorical_accuracy: 0.8848 - val_loss: 0.3821 - val_categorical_accuracy: 0.9010 - 19s/epoch - 19ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.37797 to 0.34234, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.4638 - categorical_accuracy: 0.8891 - val_loss: 0.3423 - val_categorical_accuracy: 0.9061 - 27s/epoch - 26ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.34234 to 0.33810, saving model to t_weights_0
# 1030/1030 - 28s - loss: 0.4480 - categorical_accuracy: 0.8900 - val_loss: 0.3381 - val_categorical_accuracy: 0.9070 - 28s/epoch - 27ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.33810
# 1030/1030 - 18s - loss: 0.4390 - categorical_accuracy: 0.8947 - val_loss: 0.3919 - val_categorical_accuracy: 0.8896 - 18s/epoch - 17ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.33810
# 1030/1030 - 18s - loss: 0.4201 - categorical_accuracy: 0.8986 - val_loss: 0.3591 - val_categorical_accuracy: 0.9022 - 18s/epoch - 17ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.33810
# 1030/1030 - 20s - loss: 0.4021 - categorical_accuracy: 0.9010 - val_loss: 0.4320 - val_categorical_accuracy: 0.8769 - 20s/epoch - 19ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.33810 to 0.32742, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.4081 - categorical_accuracy: 0.9022 - val_loss: 0.3274 - val_categorical_accuracy: 0.9112 - 27s/epoch - 26ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.32742
# 1030/1030 - 18s - loss: 0.3975 - categorical_accuracy: 0.9048 - val_loss: 0.4715 - val_categorical_accuracy: 0.8667 - 18s/epoch - 17ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.32742 to 0.28673, saving model to t_weights_0
# 1030/1030 - 28s - loss: 0.3808 - categorical_accuracy: 0.9078 - val_loss: 0.2867 - val_categorical_accuracy: 0.9250 - 28s/epoch - 27ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.28673
# 1030/1030 - 18s - loss: 0.3611 - categorical_accuracy: 0.9133 - val_loss: 0.2921 - val_categorical_accuracy: 0.9233 - 18s/epoch - 18ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.28673
# 1030/1030 - 20s - loss: 0.3631 - categorical_accuracy: 0.9133 - val_loss: 0.3065 - val_categorical_accuracy: 0.9165 - 20s/epoch - 19ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.28673 to 0.28075, saving model to t_weights_0
# 1030/1030 - 28s - loss: 0.3595 - categorical_accuracy: 0.9136 - val_loss: 0.2808 - val_categorical_accuracy: 0.9245 - 28s/epoch - 27ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.28075
# 1030/1030 - 19s - loss: 0.3340 - categorical_accuracy: 0.9188 - val_loss: 0.2949 - val_categorical_accuracy: 0.9189 - 19s/epoch - 19ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.28075
# 1030/1030 - 21s - loss: 0.3468 - categorical_accuracy: 0.9154 - val_loss: 0.2810 - val_categorical_accuracy: 0.9269 - 21s/epoch - 20ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.28075
# 1030/1030 - 19s - loss: 0.3372 - categorical_accuracy: 0.9174 - val_loss: 0.2875 - val_categorical_accuracy: 0.9243 - 19s/epoch - 18ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.28075
# 1030/1030 - 19s - loss: 0.3287 - categorical_accuracy: 0.9201 - val_loss: 0.2968 - val_categorical_accuracy: 0.9189 - 19s/epoch - 19ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.28075 to 0.26554, saving model to t_weights_0
# 1030/1030 - 29s - loss: 0.3183 - categorical_accuracy: 0.9225 - val_loss: 0.2655 - val_categorical_accuracy: 0.9299 - 29s/epoch - 28ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.26554
# 1030/1030 - 19s - loss: 0.3113 - categorical_accuracy: 0.9231 - val_loss: 0.2970 - val_categorical_accuracy: 0.9194 - 19s/epoch - 19ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.26554 to 0.25770, saving model to t_weights_0
# 1030/1030 - 28s - loss: 0.3201 - categorical_accuracy: 0.9223 - val_loss: 0.2577 - val_categorical_accuracy: 0.9318 - 28s/epoch - 27ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.25770
# 1030/1030 - 19s - loss: 0.3444 - categorical_accuracy: 0.9162 - val_loss: 0.2957 - val_categorical_accuracy: 0.9199 - 19s/epoch - 19ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.25770
# 1030/1030 - 20s - loss: 0.3142 - categorical_accuracy: 0.9215 - val_loss: 0.2719 - val_categorical_accuracy: 0.9269 - 20s/epoch - 20ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.25770
# 1030/1030 - 18s - loss: 0.3047 - categorical_accuracy: 0.9256 - val_loss: 0.2591 - val_categorical_accuracy: 0.9306 - 18s/epoch - 18ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.25770
# 1030/1030 - 18s - loss: 0.3078 - categorical_accuracy: 0.9254 - val_loss: 0.3588 - val_categorical_accuracy: 0.8998 - 18s/epoch - 17ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.25770 to 0.24236, saving model to t_weights_0
# 1030/1030 - 29s - loss: 0.2838 - categorical_accuracy: 0.9288 - val_loss: 0.2424 - val_categorical_accuracy: 0.9335 - 29s/epoch - 28ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.24236
# 1030/1030 - 19s - loss: 0.2936 - categorical_accuracy: 0.9279 - val_loss: 0.2506 - val_categorical_accuracy: 0.9320 - 19s/epoch - 19ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.24236
# 1030/1030 - 19s - loss: 0.3014 - categorical_accuracy: 0.9252 - val_loss: 0.2583 - val_categorical_accuracy: 0.9325 - 19s/epoch - 18ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.24236
# 1030/1030 - 20s - loss: 0.2721 - categorical_accuracy: 0.9326 - val_loss: 0.2613 - val_categorical_accuracy: 0.9306 - 20s/epoch - 20ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.24236
# 1030/1030 - 19s - loss: 0.2678 - categorical_accuracy: 0.9336 - val_loss: 0.2593 - val_categorical_accuracy: 0.9294 - 19s/epoch - 19ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.24236
# 1030/1030 - 21s - loss: 0.3063 - categorical_accuracy: 0.9245 - val_loss: 0.2726 - val_categorical_accuracy: 0.9279 - 21s/epoch - 20ms/step
# 313/313 [==============================] - 3s 9ms/step
# 0.9288834929466248 0.8488
#
#
# nrx: 25 - real: 0
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.87182, saving model to t_weights_0
# 1260/1260 - 42s - loss: 2.3667 - categorical_accuracy: 0.1580 - val_loss: 1.8718 - val_categorical_accuracy: 0.3065 - 42s/epoch - 33ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.87182 to 1.06432, saving model to t_weights_0
# 1260/1260 - 33s - loss: 1.6571 - categorical_accuracy: 0.4386 - val_loss: 1.0643 - val_categorical_accuracy: 0.6690 - 33s/epoch - 26ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.06432 to 0.96799, saving model to t_weights_0
# 1260/1260 - 32s - loss: 1.0448 - categorical_accuracy: 0.7024 - val_loss: 0.9680 - val_categorical_accuracy: 0.6931 - 32s/epoch - 25ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.96799 to 0.59882, saving model to t_weights_0
# 1260/1260 - 35s - loss: 0.7958 - categorical_accuracy: 0.7894 - val_loss: 0.5988 - val_categorical_accuracy: 0.8332 - 35s/epoch - 28ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.59882
# 1260/1260 - 26s - loss: 0.6767 - categorical_accuracy: 0.8268 - val_loss: 0.6107 - val_categorical_accuracy: 0.8311 - 26s/epoch - 21ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.59882 to 0.52322, saving model to t_weights_0
# 1260/1260 - 35s - loss: 0.5979 - categorical_accuracy: 0.8523 - val_loss: 0.5232 - val_categorical_accuracy: 0.8584 - 35s/epoch - 28ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.52322 to 0.49812, saving model to t_weights_0
# 1260/1260 - 35s - loss: 0.5642 - categorical_accuracy: 0.8601 - val_loss: 0.4981 - val_categorical_accuracy: 0.8696 - 35s/epoch - 27ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.49812 to 0.42198, saving model to t_weights_0
# 1260/1260 - 35s - loss: 0.5183 - categorical_accuracy: 0.8739 - val_loss: 0.4220 - val_categorical_accuracy: 0.8894 - 35s/epoch - 27ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.42198
# 1260/1260 - 24s - loss: 0.6686 - categorical_accuracy: 0.8231 - val_loss: 0.5194 - val_categorical_accuracy: 0.8525 - 24s/epoch - 19ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.42198
# 1260/1260 - 25s - loss: 0.4983 - categorical_accuracy: 0.8777 - val_loss: 0.4292 - val_categorical_accuracy: 0.8858 - 25s/epoch - 20ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.42198 to 0.40639, saving model to t_weights_0
# 1260/1260 - 35s - loss: 0.4589 - categorical_accuracy: 0.8867 - val_loss: 0.4064 - val_categorical_accuracy: 0.8932 - 35s/epoch - 27ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.40639 to 0.36867, saving model to t_weights_0
# 1260/1260 - 34s - loss: 0.4309 - categorical_accuracy: 0.8921 - val_loss: 0.3687 - val_categorical_accuracy: 0.9019 - 34s/epoch - 27ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.36867
# 1260/1260 - 25s - loss: 0.4247 - categorical_accuracy: 0.8951 - val_loss: 0.3956 - val_categorical_accuracy: 0.8920 - 25s/epoch - 20ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.36867
# 1260/1260 - 27s - loss: 0.4025 - categorical_accuracy: 0.8984 - val_loss: 0.4091 - val_categorical_accuracy: 0.8849 - 27s/epoch - 21ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.36867 to 0.35174, saving model to t_weights_0
# 1260/1260 - 37s - loss: 0.4077 - categorical_accuracy: 0.8976 - val_loss: 0.3517 - val_categorical_accuracy: 0.9071 - 37s/epoch - 29ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.35174
# 1260/1260 - 26s - loss: 0.4094 - categorical_accuracy: 0.8973 - val_loss: 0.4081 - val_categorical_accuracy: 0.8878 - 26s/epoch - 20ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.35174 to 0.34231, saving model to t_weights_0
# 1260/1260 - 35s - loss: 0.3834 - categorical_accuracy: 0.9033 - val_loss: 0.3423 - val_categorical_accuracy: 0.9065 - 35s/epoch - 28ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.34231
# 1260/1260 - 24s - loss: 0.3740 - categorical_accuracy: 0.9058 - val_loss: 0.3652 - val_categorical_accuracy: 0.9013 - 24s/epoch - 19ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.34231 to 0.31927, saving model to t_weights_0
# 1260/1260 - 32s - loss: 0.3550 - categorical_accuracy: 0.9099 - val_loss: 0.3193 - val_categorical_accuracy: 0.9162 - 32s/epoch - 25ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.31927
# 1260/1260 - 25s - loss: 0.3544 - categorical_accuracy: 0.9114 - val_loss: 0.3556 - val_categorical_accuracy: 0.9053 - 25s/epoch - 20ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.31927 to 0.29841, saving model to t_weights_0
# 1260/1260 - 34s - loss: 0.3430 - categorical_accuracy: 0.9135 - val_loss: 0.2984 - val_categorical_accuracy: 0.9196 - 34s/epoch - 27ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.29841
# 1260/1260 - 26s - loss: 0.5318 - categorical_accuracy: 0.8566 - val_loss: 0.3404 - val_categorical_accuracy: 0.9097 - 26s/epoch - 21ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.29841 to 0.29464, saving model to t_weights_0
# 1260/1260 - 33s - loss: 0.3335 - categorical_accuracy: 0.9158 - val_loss: 0.2946 - val_categorical_accuracy: 0.9214 - 33s/epoch - 26ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.29464 to 0.28883, saving model to t_weights_0
# 1260/1260 - 32s - loss: 0.3292 - categorical_accuracy: 0.9179 - val_loss: 0.2888 - val_categorical_accuracy: 0.9236 - 32s/epoch - 26ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.28883
# 1260/1260 - 25s - loss: 0.3094 - categorical_accuracy: 0.9226 - val_loss: 0.2941 - val_categorical_accuracy: 0.9174 - 25s/epoch - 20ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.28883
# 1260/1260 - 24s - loss: 0.3124 - categorical_accuracy: 0.9221 - val_loss: 0.3033 - val_categorical_accuracy: 0.9188 - 24s/epoch - 19ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.28883
# 1260/1260 - 26s - loss: 0.3133 - categorical_accuracy: 0.9218 - val_loss: 0.3154 - val_categorical_accuracy: 0.9113 - 26s/epoch - 20ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.28883 to 0.27196, saving model to t_weights_0
# 1260/1260 - 33s - loss: 0.3053 - categorical_accuracy: 0.9228 - val_loss: 0.2720 - val_categorical_accuracy: 0.9279 - 33s/epoch - 26ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.27196 to 0.25825, saving model to t_weights_0
# 1260/1260 - 34s - loss: 0.2887 - categorical_accuracy: 0.9269 - val_loss: 0.2583 - val_categorical_accuracy: 0.9291 - 34s/epoch - 27ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.25825
# 1260/1260 - 23s - loss: 0.2837 - categorical_accuracy: 0.9279 - val_loss: 0.2708 - val_categorical_accuracy: 0.9277 - 23s/epoch - 18ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.25825
# 1260/1260 - 24s - loss: 0.2802 - categorical_accuracy: 0.9296 - val_loss: 0.2760 - val_categorical_accuracy: 0.9252 - 24s/epoch - 19ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.25825
# 1260/1260 - 26s - loss: 0.2749 - categorical_accuracy: 0.9303 - val_loss: 0.2589 - val_categorical_accuracy: 0.9283 - 26s/epoch - 20ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.25825 to 0.25553, saving model to t_weights_0
# 1260/1260 - 33s - loss: 0.2651 - categorical_accuracy: 0.9327 - val_loss: 0.2555 - val_categorical_accuracy: 0.9307 - 33s/epoch - 26ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.25553 to 0.24883, saving model to t_weights_0
# 1260/1260 - 33s - loss: 0.2566 - categorical_accuracy: 0.9354 - val_loss: 0.2488 - val_categorical_accuracy: 0.9343 - 33s/epoch - 26ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.24883
# 1260/1260 - 23s - loss: 0.2774 - categorical_accuracy: 0.9298 - val_loss: 0.2608 - val_categorical_accuracy: 0.9317 - 23s/epoch - 18ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.24883 to 0.24722, saving model to t_weights_0
# 1260/1260 - 34s - loss: 0.2417 - categorical_accuracy: 0.9383 - val_loss: 0.2472 - val_categorical_accuracy: 0.9345 - 34s/epoch - 27ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.24722 to 0.24648, saving model to t_weights_0
# 1260/1260 - 33s - loss: 0.2474 - categorical_accuracy: 0.9372 - val_loss: 0.2465 - val_categorical_accuracy: 0.9337 - 33s/epoch - 26ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.24648 to 0.24070, saving model to t_weights_0
# 1260/1260 - 36s - loss: 0.2440 - categorical_accuracy: 0.9387 - val_loss: 0.2407 - val_categorical_accuracy: 0.9359 - 36s/epoch - 28ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.24070
# 1260/1260 - 25s - loss: 0.2540 - categorical_accuracy: 0.9351 - val_loss: 0.2494 - val_categorical_accuracy: 0.9329 - 25s/epoch - 20ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.24070
# 1260/1260 - 25s - loss: 0.2415 - categorical_accuracy: 0.9391 - val_loss: 0.2450 - val_categorical_accuracy: 0.9347 - 25s/epoch - 20ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.24070
# 1260/1260 - 24s - loss: 0.2389 - categorical_accuracy: 0.9393 - val_loss: 0.2482 - val_categorical_accuracy: 0.9319 - 24s/epoch - 19ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.24070
# 1260/1260 - 26s - loss: 0.2325 - categorical_accuracy: 0.9415 - val_loss: 0.2616 - val_categorical_accuracy: 0.9321 - 26s/epoch - 21ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.24070
# 1260/1260 - 25s - loss: 0.2351 - categorical_accuracy: 0.9401 - val_loss: 0.2939 - val_categorical_accuracy: 0.9204 - 25s/epoch - 20ms/step
# 313/313 [==============================] - 4s 9ms/step
# 0.9321024417877197 0.8635
#
#
# nrx: 0 - real: 1
# <ipython-input-1-e7494fe5acc6>:119: RuntimeWarning: invalid value encountered in true_divide
#   cls_weights = np.max(stat,axis=0)/stat
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.25672, saving model to t_weights_0
# 50/50 - 16s - loss: 2.9604 - categorical_accuracy: 0.1231 - val_loss: 2.2567 - val_categorical_accuracy: 0.1300 - 16s/epoch - 323ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.25672 to 1.91502, saving model to t_weights_0
# 50/50 - 10s - loss: 2.7599 - categorical_accuracy: 0.1937 - val_loss: 1.9150 - val_categorical_accuracy: 0.3800 - 10s/epoch - 207ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.91502 to 1.46383, saving model to t_weights_0
# 50/50 - 10s - loss: 2.2297 - categorical_accuracy: 0.3137 - val_loss: 1.4638 - val_categorical_accuracy: 0.4050 - 10s/epoch - 192ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.46383 to 1.16675, saving model to t_weights_0
# 50/50 - 10s - loss: 1.8025 - categorical_accuracy: 0.4019 - val_loss: 1.1668 - val_categorical_accuracy: 0.5650 - 10s/epoch - 194ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.16675 to 0.93529, saving model to t_weights_0
# 50/50 - 11s - loss: 1.5238 - categorical_accuracy: 0.4844 - val_loss: 0.9353 - val_categorical_accuracy: 0.6800 - 11s/epoch - 222ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.93529 to 0.73269, saving model to t_weights_0
# 50/50 - 10s - loss: 1.2276 - categorical_accuracy: 0.5863 - val_loss: 0.7327 - val_categorical_accuracy: 0.7700 - 10s/epoch - 195ms/step
# Epoch 7/100
#
# ...
# 307/307 [==============================] - 4s 9ms/step
# 0.9429391026496887 0.7839795918367347
#
#
# nrx: 20 - real: 4
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.03583, saving model to t_weights_0
# 1030/1030 - 34s - loss: 1.8941 - categorical_accuracy: 0.3705 - val_loss: 1.0358 - val_categorical_accuracy: 0.6643 - 34s/epoch - 33ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.03583 to 0.70371, saving model to t_weights_0
# 1030/1030 - 26s - loss: 1.0428 - categorical_accuracy: 0.7065 - val_loss: 0.7037 - val_categorical_accuracy: 0.8057 - 26s/epoch - 25ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.70371 to 0.54471, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.7811 - categorical_accuracy: 0.8014 - val_loss: 0.5447 - val_categorical_accuracy: 0.8462 - 27s/epoch - 26ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.54471
# 1030/1030 - 19s - loss: 0.6170 - categorical_accuracy: 0.8509 - val_loss: 0.6717 - val_categorical_accuracy: 0.8016 - 19s/epoch - 19ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.54471 to 0.40799, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.5424 - categorical_accuracy: 0.8701 - val_loss: 0.4080 - val_categorical_accuracy: 0.8866 - 27s/epoch - 26ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.40799
# 1030/1030 - 18s - loss: 0.4737 - categorical_accuracy: 0.8885 - val_loss: 0.4598 - val_categorical_accuracy: 0.8737 - 18s/epoch - 18ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.40799 to 0.38902, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.5597 - categorical_accuracy: 0.8607 - val_loss: 0.3890 - val_categorical_accuracy: 0.8912 - 26s/epoch - 26ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.38902
# 1030/1030 - 20s - loss: 0.5896 - categorical_accuracy: 0.8511 - val_loss: 0.4409 - val_categorical_accuracy: 0.8790 - 20s/epoch - 19ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.38902 to 0.31744, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.4493 - categorical_accuracy: 0.8962 - val_loss: 0.3174 - val_categorical_accuracy: 0.9196 - 27s/epoch - 27ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.31744
# 1030/1030 - 18s - loss: 0.3995 - categorical_accuracy: 0.9079 - val_loss: 0.4132 - val_categorical_accuracy: 0.8817 - 18s/epoch - 18ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.31744 to 0.31424, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.4067 - categorical_accuracy: 0.9053 - val_loss: 0.3142 - val_categorical_accuracy: 0.9191 - 27s/epoch - 26ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.31424 to 0.28051, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.4333 - categorical_accuracy: 0.9005 - val_loss: 0.2805 - val_categorical_accuracy: 0.9266 - 26s/epoch - 25ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.28051
# 1030/1030 - 18s - loss: 0.5768 - categorical_accuracy: 0.8516 - val_loss: 0.8434 - val_categorical_accuracy: 0.7729 - 18s/epoch - 18ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.28051
# 1030/1030 - 19s - loss: 0.4180 - categorical_accuracy: 0.9031 - val_loss: 0.2903 - val_categorical_accuracy: 0.9232 - 19s/epoch - 18ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.28051
# 1030/1030 - 18s - loss: 0.3471 - categorical_accuracy: 0.9220 - val_loss: 0.3454 - val_categorical_accuracy: 0.9082 - 18s/epoch - 18ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.28051 to 0.25330, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.3562 - categorical_accuracy: 0.9187 - val_loss: 0.2533 - val_categorical_accuracy: 0.9364 - 27s/epoch - 27ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.25330
# 1030/1030 - 19s - loss: 0.3154 - categorical_accuracy: 0.9266 - val_loss: 0.3080 - val_categorical_accuracy: 0.9225 - 19s/epoch - 19ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.25330 to 0.24298, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.3287 - categorical_accuracy: 0.9229 - val_loss: 0.2430 - val_categorical_accuracy: 0.9359 - 27s/epoch - 26ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.24298 to 0.23695, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.3266 - categorical_accuracy: 0.9225 - val_loss: 0.2369 - val_categorical_accuracy: 0.9376 - 27s/epoch - 26ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.23695
# 1030/1030 - 18s - loss: 0.2847 - categorical_accuracy: 0.9347 - val_loss: 0.2871 - val_categorical_accuracy: 0.9276 - 18s/epoch - 18ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.23695
# 1030/1030 - 19s - loss: 0.3101 - categorical_accuracy: 0.9269 - val_loss: 0.2453 - val_categorical_accuracy: 0.9371 - 19s/epoch - 18ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.23695
# 1030/1030 - 18s - loss: 0.2725 - categorical_accuracy: 0.9361 - val_loss: 0.3214 - val_categorical_accuracy: 0.9123 - 18s/epoch - 18ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.23695 to 0.22052, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.2813 - categorical_accuracy: 0.9356 - val_loss: 0.2205 - val_categorical_accuracy: 0.9439 - 26s/epoch - 25ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.22052
# 1030/1030 - 19s - loss: 0.2847 - categorical_accuracy: 0.9330 - val_loss: 0.2833 - val_categorical_accuracy: 0.9208 - 19s/epoch - 18ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.22052
# 1030/1030 - 19s - loss: 0.2785 - categorical_accuracy: 0.9361 - val_loss: 0.3291 - val_categorical_accuracy: 0.9191 - 19s/epoch - 19ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.22052 to 0.21152, saving model to t_weights_0
# 1030/1030 - 27s - loss: 0.2654 - categorical_accuracy: 0.9380 - val_loss: 0.2115 - val_categorical_accuracy: 0.9456 - 27s/epoch - 26ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.21152
# 1030/1030 - 18s - loss: 0.2782 - categorical_accuracy: 0.9349 - val_loss: 0.2247 - val_categorical_accuracy: 0.9432 - 18s/epoch - 17ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.21152
# 1030/1030 - 20s - loss: 0.2584 - categorical_accuracy: 0.9384 - val_loss: 0.2148 - val_categorical_accuracy: 0.9453 - 20s/epoch - 19ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.21152
# 1030/1030 - 18s - loss: 0.2534 - categorical_accuracy: 0.9403 - val_loss: 0.2194 - val_categorical_accuracy: 0.9412 - 18s/epoch - 17ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.21152 to 0.20156, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.2471 - categorical_accuracy: 0.9410 - val_loss: 0.2016 - val_categorical_accuracy: 0.9468 - 26s/epoch - 26ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.20156
# 1030/1030 - 18s - loss: 0.2865 - categorical_accuracy: 0.9330 - val_loss: 0.2361 - val_categorical_accuracy: 0.9349 - 18s/epoch - 17ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.20156 to 0.19837, saving model to t_weights_0
# 1030/1030 - 28s - loss: 0.2484 - categorical_accuracy: 0.9410 - val_loss: 0.1984 - val_categorical_accuracy: 0.9487 - 28s/epoch - 27ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.19837
# 1030/1030 - 19s - loss: 0.2199 - categorical_accuracy: 0.9490 - val_loss: 0.2012 - val_categorical_accuracy: 0.9485 - 19s/epoch - 18ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.19837 to 0.19374, saving model to t_weights_0
# 1030/1030 - 26s - loss: 0.2276 - categorical_accuracy: 0.9459 - val_loss: 0.1937 - val_categorical_accuracy: 0.9509 - 26s/epoch - 25ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.19374
# 1030/1030 - 18s - loss: 0.2300 - categorical_accuracy: 0.9455 - val_loss: 0.2465 - val_categorical_accuracy: 0.9342 - 18s/epoch - 17ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.19374
# 1030/1030 - 20s - loss: 0.2299 - categorical_accuracy: 0.9457 - val_loss: 0.1951 - val_categorical_accuracy: 0.9509 - 20s/epoch - 19ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.19374
# 1030/1030 - 18s - loss: 0.2310 - categorical_accuracy: 0.9465 - val_loss: 0.2022 - val_categorical_accuracy: 0.9453 - 18s/epoch - 17ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.19374
# 1030/1030 - 18s - loss: 0.2140 - categorical_accuracy: 0.9499 - val_loss: 0.2149 - val_categorical_accuracy: 0.9395 - 18s/epoch - 17ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.19374
# 1030/1030 - 19s - loss: 0.2144 - categorical_accuracy: 0.9504 - val_loss: 0.2200 - val_categorical_accuracy: 0.9415 - 19s/epoch - 18ms/step
# 307/307 [==============================] - 4s 8ms/step
# 0.9587078094482422 0.8003061224489796
#
#
# nrx: 25 - real: 4
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.00834, saving model to t_weights_0
# 1260/1260 - 38s - loss: 1.7986 - categorical_accuracy: 0.3852 - val_loss: 1.0083 - val_categorical_accuracy: 0.6859 - 38s/epoch - 30ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.00834 to 0.66017, saving model to t_weights_0
# 1260/1260 - 32s - loss: 0.9854 - categorical_accuracy: 0.7195 - val_loss: 0.6602 - val_categorical_accuracy: 0.8088 - 32s/epoch - 25ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.66017 to 0.55526, saving model to t_weights_0
# 1260/1260 - 30s - loss: 0.7351 - categorical_accuracy: 0.8051 - val_loss: 0.5553 - val_categorical_accuracy: 0.8487 - 30s/epoch - 24ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.55526
# 1260/1260 - 22s - loss: 0.6570 - categorical_accuracy: 0.8305 - val_loss: 0.5604 - val_categorical_accuracy: 0.8388 - 22s/epoch - 18ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.55526 to 0.49334, saving model to t_weights_0
# 1260/1260 - 31s - loss: 0.5498 - categorical_accuracy: 0.8608 - val_loss: 0.4933 - val_categorical_accuracy: 0.8644 - 31s/epoch - 25ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.49334 to 0.43425, saving model to t_weights_0
# 1260/1260 - 31s - loss: 0.5070 - categorical_accuracy: 0.8708 - val_loss: 0.4343 - val_categorical_accuracy: 0.8819 - 31s/epoch - 25ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.43425 to 0.42583, saving model to t_weights_0
# 1260/1260 - 32s - loss: 0.4799 - categorical_accuracy: 0.8801 - val_loss: 0.4258 - val_categorical_accuracy: 0.8849 - 32s/epoch - 25ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.42583 to 0.35697, saving model to t_weights_0
# 1260/1260 - 31s - loss: 0.4336 - categorical_accuracy: 0.8923 - val_loss: 0.3570 - val_categorical_accuracy: 0.9057 - 31s/epoch - 24ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.35697
# 1260/1260 - 24s - loss: 0.4201 - categorical_accuracy: 0.8968 - val_loss: 0.3754 - val_categorical_accuracy: 0.8986 - 24s/epoch - 19ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.35697 to 0.31659, saving model to t_weights_0
# 1260/1260 - 29s - loss: 0.3961 - categorical_accuracy: 0.9013 - val_loss: 0.3166 - val_categorical_accuracy: 0.9134 - 29s/epoch - 23ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.31659
# 1260/1260 - 24s - loss: 0.3756 - categorical_accuracy: 0.9075 - val_loss: 0.3200 - val_categorical_accuracy: 0.9126 - 24s/epoch - 19ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.31659
# 1260/1260 - 22s - loss: 0.3544 - categorical_accuracy: 0.9120 - val_loss: 0.3457 - val_categorical_accuracy: 0.9055 - 22s/epoch - 17ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.31659 to 0.29817, saving model to t_weights_0
# 1260/1260 - 32s - loss: 0.3565 - categorical_accuracy: 0.9122 - val_loss: 0.2982 - val_categorical_accuracy: 0.9214 - 32s/epoch - 26ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.29817
# 1260/1260 - 22s - loss: 0.3278 - categorical_accuracy: 0.9189 - val_loss: 0.3125 - val_categorical_accuracy: 0.9184 - 22s/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.29817 to 0.26865, saving model to t_weights_0
# 1260/1260 - 31s - loss: 0.3344 - categorical_accuracy: 0.9168 - val_loss: 0.2686 - val_categorical_accuracy: 0.9273 - 31s/epoch - 25ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.26865 to 0.26696, saving model to t_weights_0
# 1260/1260 - 32s - loss: 0.3038 - categorical_accuracy: 0.9245 - val_loss: 0.2670 - val_categorical_accuracy: 0.9287 - 32s/epoch - 25ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.26696
# 1260/1260 - 23s - loss: 0.3203 - categorical_accuracy: 0.9216 - val_loss: 0.2736 - val_categorical_accuracy: 0.9269 - 23s/epoch - 19ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.26696 to 0.25927, saving model to t_weights_0
# 1260/1260 - 37s - loss: 0.2883 - categorical_accuracy: 0.9280 - val_loss: 0.2593 - val_categorical_accuracy: 0.9311 - 37s/epoch - 29ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.25927
# 1260/1260 - 26s - loss: 0.2836 - categorical_accuracy: 0.9289 - val_loss: 0.2810 - val_categorical_accuracy: 0.9261 - 26s/epoch - 21ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.25927
# 1260/1260 - 23s - loss: 0.2788 - categorical_accuracy: 0.9313 - val_loss: 0.2915 - val_categorical_accuracy: 0.9216 - 23s/epoch - 18ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.25927
# 1260/1260 - 27s - loss: 0.2651 - categorical_accuracy: 0.9338 - val_loss: 0.3056 - val_categorical_accuracy: 0.9204 - 27s/epoch - 22ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.25927 to 0.24702, saving model to t_weights_0
# 1260/1260 - 34s - loss: 0.2816 - categorical_accuracy: 0.9299 - val_loss: 0.2470 - val_categorical_accuracy: 0.9341 - 34s/epoch - 27ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.24702 to 0.24200, saving model to t_weights_0
# 1260/1260 - 36s - loss: 0.2613 - categorical_accuracy: 0.9350 - val_loss: 0.2420 - val_categorical_accuracy: 0.9345 - 36s/epoch - 29ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.24200
# 1260/1260 - 27s - loss: 0.2564 - categorical_accuracy: 0.9364 - val_loss: 0.5116 - val_categorical_accuracy: 0.8789 - 27s/epoch - 21ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.24200
# 1260/1260 - 26s - loss: 0.2527 - categorical_accuracy: 0.9388 - val_loss: 0.2882 - val_categorical_accuracy: 0.9228 - 26s/epoch - 20ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.24200 to 0.24113, saving model to t_weights_0
# 1260/1260 - 36s - loss: 0.2375 - categorical_accuracy: 0.9403 - val_loss: 0.2411 - val_categorical_accuracy: 0.9351 - 36s/epoch - 28ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.24113 to 0.23428, saving model to t_weights_0
# 1260/1260 - 35s - loss: 0.2382 - categorical_accuracy: 0.9406 - val_loss: 0.2343 - val_categorical_accuracy: 0.9383 - 35s/epoch - 28ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.23428 to 0.22007, saving model to t_weights_0
# 1260/1260 - 37s - loss: 0.2356 - categorical_accuracy: 0.9420 - val_loss: 0.2201 - val_categorical_accuracy: 0.9416 - 37s/epoch - 30ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.22007
# 1260/1260 - 26s - loss: 0.2427 - categorical_accuracy: 0.9409 - val_loss: 0.2225 - val_categorical_accuracy: 0.9430 - 26s/epoch - 21ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.22007
# 1260/1260 - 28s - loss: 0.2207 - categorical_accuracy: 0.9451 - val_loss: 0.2649 - val_categorical_accuracy: 0.9351 - 28s/epoch - 23ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.22007
# 1260/1260 - 26s - loss: 0.2253 - categorical_accuracy: 0.9443 - val_loss: 0.2263 - val_categorical_accuracy: 0.9422 - 26s/epoch - 21ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.22007
# 1260/1260 - 26s - loss: 0.2153 - categorical_accuracy: 0.9472 - val_loss: 0.2413 - val_categorical_accuracy: 0.9385 - 26s/epoch - 21ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.22007
# 1260/1260 - 26s - loss: 0.2100 - categorical_accuracy: 0.9483 - val_loss: 0.3081 - val_categorical_accuracy: 0.9202 - 26s/epoch - 20ms/step
# 307/307 [==============================] - 4s 10ms/step
# 0.9483819603919983 0.7740816326530612

# %%
matplotlib.rcParams['figure.dpi'] = 100
plt.errorbar(np.array(nrx_list)+1,np.mean(smTest_results,0),np.std(smTest_results,0),capsize=4)
plt.errorbar(np.array(nrx_list)+1,np.mean(dfTest_results,0),np.std(dfTest_results,0),capsize=4)
plt.legend(['Same Rx(s)','Diff. Rx'])
plt.xlabel('N Train Rx')
plt.ylabel('Class. Accuracy')
#plt.xticks(range(0,len(nrx_list),2))
plt.grid()
print(np.mean(dfTest_results,0).tolist())
# Out:
# [0.1495342857142857, 0.6692930612244898, 0.7623640816326531, 0.801850612244898, 0.8249138775510204, 0.8370730612244897]

# %%
# !cp -r /content/weights /content/drive/MyDrive/lstm
